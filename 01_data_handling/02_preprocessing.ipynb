# %% [markdown]
# ## Basics

# %% [markdown]
# ### Imports & Settings

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
import html
import os
import requests
from urllib.parse import quote
from itertools import pairwise
import textwrap
from matplotlib.patches import FancyBboxPatch

# %%
# figure style
ACCENT = "#d6614a"
PAL_DEFAULT = sns.color_palette("deep")  # fixed categorical palette
PAL_CUSTOM = sns.color_palette([ACCENT] + [colour for i, colour in enumerate(PAL_DEFAULT.as_hex()) if i != 1])

sns.set_theme()
sns.set_palette(PAL_CUSTOM)

# %% [markdown]
# ### Working Directory Path

# %%
# Google Drive Path for Running on Colab
# from google.colab import drive
# drive.mount('/content/drive')
# path = "drive/MyDrive/MSc Thesis/"

# %%
# Local Path for Running Locally
path = "../data/"

# %% [markdown]
# ### Read Data

# %%
data = pd.read_csv(path + 'agora12_data.csv')
data
# Out:
#                                Id Collection    Type                 Name  \
# 0        Agora:Object:Agora XII:1      Agora  Object     Agora XII, no. 1
# 1        Agora:Object:Agora XII:2      Agora  Object     Agora XII, no. 2
# 2        Agora:Object:Agora XII:3      Agora  Object     Agora XII, no. 3
# 3        Agora:Object:Agora XII:4      Agora  Object     Agora XII, no. 4
# 4        Agora:Object:Agora XII:5      Agora  Object     Agora XII, no. 5
# ...                           ...        ...     ...                  ...
# 1995  Agora:Object:Agora XII:2036      Agora  Object  Agora XII, no. 2036
# 1996  Agora:Object:Agora XII:2037      Agora  Object  Agora XII, no. 2037
# 1997  Agora:Object:Agora XII:2038      Agora  Object  Agora XII, no. 2038
# 1998  Agora:Object:Agora XII:2039      Agora  Object  Agora XII, no. 2039
# 1999  Agora:Object:Agora XII:2040      Agora  Object  Agora XII, no. 2040
#
#      UserGroup  AgoraVolume  AgoraNumber  \
# 0       Public           12            1
# 1       Public           12            2
# 2       Public           12            3
# 3       Public           12            4
# 4       Public           12            5
# ...        ...          ...          ...
# 1995    Public           12         2036
# 1996    Public           12         2037
# 1997    Public           12         2038
# 1998    Public           12         2039
# 1999    Public           12         2040
#
#                                                    Text PublishedNumber  \
# 0     Foot missing.
#
# Offset neck and echinoid mouth;...         AV 12.1
# 1     Spreading ring foot with torus outer and conve...         AV 12.2
# 2     Flaring ring foot. Torus mouth. Ridge at junct...         AV 12.3
# 3     Ring foot. Echinoid mouth inset from neck and ...         AV 12.4
# 4     Echinus ring foot. Torus mouth; strap handles....         AV 12.5
# ...                                                 ...             ...
# 1995  Fragment of rim and floor with handle.
#
# Deep b...      AV 12.2036
# 1996  Handles missing.
#
# Basin and lid; handles proba...      AV 12.2037
# 1997  Small series. Plain flat-topped rim; flaring b...      AV 12.2038
# 1998  Small series. Rim flat on top, roughly moulded...      AV 12.2039
# 1999  Stand and floor fragment.
#
# Lower edge of stand...      AV 12.2040
#
#                                          Classification  ...     Deposit  \
# 0      Black and Plain Pottery | Amphora | Neck-Amphora  ...      Q 13:5
# 1      Black and Plain Pottery | Amphora | Neck-Amphora  ...       D 7:2
# 2      Black and Plain Pottery | Amphora | Neck-Amphora  ...  G 11:3-POU
# 3      Black and Plain Pottery | Amphora | Neck-Amphora  ...    U 19:2-U
# 4             Bottom Fill: Late 6th c. B.C., at latest.  ...  V 24:2-POU
# ...                                                 ...  ...         ...
# 1995  Black and Plain Pottery | Cooking Devices | Es...  ...      O 18:2
# 1996  Black and Plain Pottery | Cooking Devices | Es...  ...      G 11:4
# 1997  Black and Plain Pottery | Cooking Devices | Es...  ...       H 7:1
# 1998  Black and Plain Pottery | Cooking Devices | Es...  ...      C 12:2
# 1999  Black and Plain Pottery | Cooking Devices | Es...  ...  C 19:5 (b)
#
#                                              Dimensions  \
# 0                           H. rest. 0.24; diam. 0.174.
# 1                                H. 0.292; diam. 0.285.
# 2                                 H. 0.21; diam. 0.149.
# 3                                 H. 0.272; diam. 0.22.
# 4                                H. 0.254; diam. 0.181.
# ...                                                 ...
# 1995                                                NaN
# 1996  H. of basin 0.143; diam. 0.36; diam. of lid 0....
# 1997                             H. 0.104; diam. 0.246.
# 1998                                                NaN
# 1999                                                NaN
#
#                                Chronology ChronologyRange  \
# 0                            575-550 B.C.       -575;-550
# 1                        Late 6th c. B.C.       -525;-500
# 2                            Ca. 500 B.C.            -500
# 3                            Ca. 500 B.C.            -500
# 4                        Late 6th c. B.C.       -525;-500
# ...                                   ...             ...
# 1995             Context ca. 350-320 B.C.       -350;-320
# 1996  Context, second half of 4th c. B.C.       -350;-301
# 1997             Context ca. 435-425 B.C.       -435;-425
# 1998             Context ca. 375-325 B.C.       -375;-325
# 1999                  Context 4th c. B.C.       -400;-300
#
#                                            Sort               Sibling Edges  \
# 0     18+0000000001 Agora 0000000012:0000000001  Agora:Object:P 24986     1
# 1     18+0000000001 Agora 0000000012:0000000002   Agora:Object:P 7266     1
# 2     18+0000000001 Agora 0000000012:0000000003  Agora:Object:P 12781     1
# 3     18+0000000001 Agora 0000000012:0000000004  Agora:Object:P 26725     1
# 4     18+0000000001 Agora 0000000012:0000000005  Agora:Object:P 13014     1
# ...                                         ...                   ...   ...
# 1995  18+0000000001 Agora 0000000012:0000002036  Agora:Object:P 13569     1
# 1996  18+0000000001 Agora 0000000012:0000002037   Agora:Object:P 6218     1
# 1997  18+0000000001 Agora 0000000012:0000002038   Agora:Object:P 4870     1
# 1998  18+0000000001 Agora 0000000012:0000002039   Agora:Object:P 8304     1
# 1999  18+0000000001 Agora 0000000012:0000002040  Agora:Object:P 19564     1
#
#                                            Bibliography  \
# 0     &lt;i&gt;Hesperia,&lt;/i&gt; XXV, 1956, pl. 18 k.
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1995                                                NaN
# 1996                                                NaN
# 1997  &lt;i&gt;Hesperia,&lt;/i&gt; VI, 1937, p. 52, ...
# 1998                                                NaN
# 1999                                                NaN
#
#                         Parent AgoraLetter
# 0     Agora:Image:2012.54.1450         NaN
# 1        Agora:Drawing:DA 6616         NaN
# 2                          NaN         NaN
# 3                          NaN         NaN
# 4     Agora:Image:2012.27.0009         NaN
# ...                        ...         ...
# 1995     Agora:Drawing:DA 8040         NaN
# 1996  Agora:Image:2012.55.1261         NaN
# 1997  Agora:Image:2012.25.0184         NaN
# 1998  Agora:Image:2012.55.1268         NaN
# 1999                       NaN         NaN
#
# [2000 rows x 21 columns]

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### Info

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Id               2000 non-null   object
#  1   Collection       2000 non-null   object
#  2   Type             2000 non-null   object
#  3   Name             2000 non-null   object
#  4   UserGroup        2000 non-null   object
#  5   AgoraVolume      2000 non-null   int64
#  6   AgoraNumber      2000 non-null   int64
#  7   Text             2000 non-null   object
#  8   PublishedNumber  2000 non-null   object
#  9   Classification   2000 non-null   object
#  10  Class            2000 non-null   object
#  11  Deposit          1789 non-null   object
#  12  Dimensions       870 non-null    object
#  13  Chronology       1994 non-null   object
#  14  ChronologyRange  1990 non-null   object
#  15  Sort             2000 non-null   object
#  16  Sibling          2000 non-null   object
#  17  Edges            2000 non-null   int64
#  18  Bibliography     217 non-null    object
#  19  Parent           1366 non-null   object
#  20  AgoraLetter      1 non-null      object
# dtypes: int64(3), object(18)
# memory usage: 328.3+ KB

# %% [markdown]
# ### Missing Values

# %%
((data.isna().sum() / len(data)) * 100).round(2).astype(str) + '%'
# Out:
# Id                   0.0%
# Collection           0.0%
# Type                 0.0%
# Name                 0.0%
# UserGroup            0.0%
# AgoraVolume          0.0%
# AgoraNumber          0.0%
# Text                 0.0%
# PublishedNumber      0.0%
# Classification       0.0%
# Class                0.0%
# Deposit            10.55%
# Dimensions          56.5%
# Chronology           0.3%
# ChronologyRange      0.5%
# Sort                 0.0%
# Sibling              0.0%
# Edges                0.0%
# Bibliography       89.15%
# Parent              31.7%
# AgoraLetter        99.95%
# dtype: object

# %%
colours = ['lightgreen', 'salmon']  # green = present, red = missing
plt.figure(figsize=(8, 7))
sns.heatmap(data.isnull(), cmap=colours, cbar=False)
plt.yticks(range(0, len(data), 100), [f"{i}" for i in range(0, len(data), 100)])
plt.show()

# %% [markdown]
# ### Field: "Dimensions"

# %%
labels = {}
for entry in data["Dimensions"].dropna():
    dim = html.unescape(entry)
    dim = re.sub(r"<.*?>", "", dim)
    dim = dim.lower()
    measurements = dim.split(';')
    for measurement in measurements:
        measurement = measurement.strip().rstrip('.')
        # label = measurement.split()[:-1]
        # label = ' '.join(label)
        labelMatch = re.match(r'^(.*?)(?=\d)', measurement)
        if not labelMatch:
            continue
        label = labelMatch.group(1).strip()

        labels[label] = labels[label] + 1 if label in labels else 1
        # labels.add(label)
        # print(label)
labels = dict(sorted(labels.items(), key=lambda x: x[1], reverse=True))
labels
# Out:
# {'diam.': 543,
#  'h.': 512,
#  'h. pres.': 131,
#  'diam. of rim': 69,
#  'diam. est.': 55,
#  'h. to rim': 39,
#  'diam. of foot': 35,
#  'max. dim.': 15,
#  'diam. of foot est.': 13,
#  'diam. of rim est.': 11,
#  'diam. ca.': 7,
#  'diam. at rim': 6,
#  'diam. of base': 6,
#  'h. of bowl': 6,
#  'l. pres.': 5,
#  'diam. of lid': 5,
#  'diam. as restored': 4,
#  'h. as restored': 4,
#  'total h.': 4,
#  'h. of lid': 4,
#  'diam. of bowl': 4,
#  'h. rest.': 3,
#  'h. with lid': 3,
#  'diam. rest.': 3,
#  'l.': 3,
#  'diam. of foot ca.': 2,
#  'h. pres. to rim,': 2,
#  'h. of largest fragment': 2,
#  'max. diam.': 2,
#  'h. pres. ca.': 2,
#  'diam. of rim ca.': 2,
#  'diam. est. ca.': 2,
#  'diam. of bottom': 2,
#  'diam. of body': 2,
#  'h. with handle': 2,
#  'diam. not less than': 2,
#  'w.': 2,
#  'diam. of rim of spout': 2,
#  'h. overall': 2,
#  'diam. at rim ca.': 1,
#  'diam of rim, as restored': 1,
#  'h. pres. of upper part ca.': 1,
#  'h. ca.': 1,
#  'w. of handle': 1,
#  'h. pres. to rim': 1,
#  'diam. of base est.': 1,
#  'to top of handle': 1,
#  'diam. at keel': 1,
#  'length as reconstructed,': 1,
#  'h. of bowl as preserved': 1,
#  'diam. of foot-ring est.': 1,
#  'max. l.': 1,
#  'diam. of lip est.': 1,
#  'h. as restored ca.': 1,
#  'max. dim. of larger fragment': 1,
#  'diam. of center': 1,
#  'total h. pres.': 1,
#  'h. pres. of lid': 1,
#  'diam. of lid est.': 1,
#  'diam of lid': 1,
#  'diam. est. of bowl': 1,
#  'diam. est. of rim': 1,
#  'h. to top of spout': 1,
#  'h. pres., upper part,': 1,
#  'lower part,': 1,
#  'diam. at interior of neck ca.': 1,
#  'diam. at lip': 1,
#  'diam. at lip est. ca.': 1,
#  'below handles': 1,
#  'h. without lid': 1,
#  'h. est.': 1,
#  'h. pres. a)': 1,
#  'b)': 1,
#  'l. as restored': 1,
#  'diam. irregular, not over': 1,
#  'diam. at rim est.': 1,
#  'diam. pres.': 1,
#  'diam. of basin': 1,
#  'of base': 1,
#  'width of handle': 1,
#  'h. to top of handle': 1,
#  'l. rest.': 1,
#  'diam. of spout': 1,
#  'h. to start of handle': 1,
#  'top,': 1,
#  'top': 1,
#  'h. of basin': 1}

# %%
def frequencyBars(labels, fieldName, threshold=0.1):
    totalCount = data.shape[0]
    labelsFiltered = {k: v for k, v in labels.items() if round(100 * v / totalCount, 2) > threshold}
    excludedCount = len(labels) - len(labelsFiltered)

    labelsR = dict(reversed(list(labelsFiltered.items())))
    plt.figure(figsize=(10, 18))
    plt.barh(range(len(labelsR)), list(labelsR.values()))
    plt.yticks(range(len(labelsR)), list(labelsR.keys()))
    plt.yticks(fontsize=8)
    plt.xlabel('Frequency')
    plt.ylabel(fieldName)
    plt.title(f"Frequency of {fieldName}")
    for index, value in enumerate(labelsR.values()):
        plt.text(value + 2, index, f'{round(100 * value / totalCount, 2)}%', va='center',
                 fontsize=8)  # Adjust +2 for spacing
    plt.show()

    print(f"{excludedCount} more {fieldName} with frequency <= {threshold}%")

# %%
frequencyBars(labels, 'Dimensions')
# Out:
# 62 more Dimensions with frequency <= 0.1%

# %%
mostFreq = list(labels.items())[0]
perc = mostFreq[1] / data.shape[0]
plt.figure(figsize=(5, 5))
plt.pie([perc, 1 - perc], labels=[f'filled "{mostFreq[0]}"', f'null "{mostFreq[0]}"'], colors=['lightgreen', 'salmon'])
plt.title('Missing Values of Most Frequent Measure')
plt.show()

# %% [markdown]
# ### Fields: "Classification" & "Class"

# %%
def uniqueClassFreq(field):
    classes = dict()
    for entry in data[field].dropna():
        entry = html.unescape(entry)
        entry = re.sub(r"<.*?>", "", entry)
        entry = entry.lower()
        entryClasses = entry.split('|')
        for entryClass in entryClasses:
            entryClass = entryClass.strip()
            if not entryClass:
                continue
            classes[entryClass] = classes[entryClass] + 1 if entryClass in classes else 1
    return dict(sorted(classes.items(), key=lambda x: x[1], reverse=True))

# %%
classificationClasses = uniqueClassFreq('Classification')
classificationClasses
# Out:
# {'black and plain pottery': 1860,
#  'small bowl and saltcellar': 109,
#  'oinochoe': 104,
#  'lekane': 100,
#  'kantharos': 92,
#  'jug': 83,
#  'plate': 81,
#  'imported': 75,
#  'skyphos': 73,
#  'miniature': 71,
#  'saltcellar': 66,
#  'lekanis': 66,
#  'cup': 64,
#  'stemless': 63,
#  'amphora and amphoriskos': 63,
#  'site': 60,
#  'small': 57,
#  'cup-skyphos': 56,
#  'one-handler': 56,
#  'bowl': 55,
#  'olpe': 53,
#  'plans and drawings': 53,
#  'hellenistic pottery and wheelmade table ware': 52,
#  'plain rim': 52,
#  'lekythos': 49,
#  'small bowl': 46,
#  'by type': 45,
#  'large': 45,
#  'mug': 44,
#  'askos': 41,
#  'type c': 38,
#  'main sequence': 38,
#  'ca. 525-ca. 300 b.c.': 38,
#  'black': 37,
#  'mortar': 36,
#  'chytra': 36,
#  'attic': 35,
#  'cup-kantharos': 35,
#  'pyxis': 33,
#  'variants': 32,
#  'stemmed dish': 32,
#  'delicate class': 31,
#  'outturned rim': 30,
#  'louterion': 30,
#  'decorated basin and stand fragments': 30,
#  'chous': 29,
#  'shape 3': 29,
#  'table amphora': 29,
#  'bolsal': 28,
#  'light wall': 28,
#  'banded': 27,
#  'fragments used as ostraka': 26,
#  'corinthian type': 25,
#  'various fabrics': 25,
#  'moulded rim': 24,
#  'attic variants and imported plain': 24,
#  'hydria': 23,
#  'burials': 23,
#  'narrow-necked': 23,
#  'cooking devices': 23,
#  'pheidias shape': 22,
#  'type a': 22,
#  '6th and 5th century shapes': 22,
#  'echinus wall': 22,
#  'rilled rim': 22,
#  'tile fabrics': 22,
#  'lopas': 22,
#  'miscellaneous household utensils': 22,
#  'pelike': 21,
#  'large bowl': 21,
#  'vessels for food service': 21,
#  'squat lekythos': 21,
#  'roads': 20,
#  'panathenaic way': 20,
#  'corinthian': 20,
#  'storage-bin': 20,
#  'household ware': 20,
#  'special collections': 19,
#  'footed': 19,
#  'patterned': 19,
#  'thurible': 19,
#  'trefoil cooking ware and related': 19,
#  'banded round-mouth': 18,
#  '6th century types': 18,
#  'attic type': 18,
#  'subgeometric survivals': 18,
#  'concave lip': 18,
#  'early': 18,
#  '6th century and early 5th': 18,
#  'standard': 18,
#  'concave wall': 18,
#  'pithos': 18,
#  'common type': 18,
#  'wide-mouthed and lidded': 18,
#  'agora and environs': 17,
#  'votive': 17,
#  'amphora': 16,
#  'decoration and undersides': 16,
#  'deep': 16,
#  'attic and imported': 16,
#  'miscellaneous shapes': 16,
#  'miscellaneous': 15,
#  'by area': 15,
#  'type d': 15,
#  'household lekanis': 15,
#  'mushroom jug': 14,
#  'footless': 14,
#  'drinking cups': 14,
#  'classical kantharos and related shapes': 14,
#  'broad rim': 14,
#  'later and light': 14,
#  'convex and small': 14,
#  'fish-plate': 14,
#  'black deianeira': 14,
#  'lids for ribbon-handled lekanides or variants': 14,
#  'covered bowl': 14,
#  'stemmed': 14,
#  'vases from sacrificial pyres': 14,
#  'kados': 14,
#  'wide-mouthed': 14,
#  'gray ware': 14,
#  'handles turned up to rim': 14,
#  'griddle': 14,
#  'bean-parcher': 14,
#  'miscellaneous round-mouth': 13,
#  'kalathos': 13,
#  'amphoriskos': 13,
#  'cooking ware': 13,
#  'thickened': 13,
#  'rounded or outcurved rim': 13,
#  'collar rim': 13,
#  'stamped class': 12,
#  'table and storage amphora': 12,
#  'impressed or incised decoration': 12,
#  'ladle': 12,
#  'eschara': 12,
#  'lidless pelike': 11,
#  'trefoil': 11,
#  'incurving rim': 11,
#  'thickened edge': 11,
#  'globular body': 11,
#  'lidded with ribbon handles': 11,
#  'various shapes': 11,
#  'small or medium-sized versions': 11,
#  'tall-necked': 11,
#  'krater': 10,
#  'heavy wall': 10,
#  'bowl, small bowl, and saltcellar': 10,
#  'normal version': 10,
#  'psykter': 9,
#  'type b': 9,
#  'class of athens 1104': 9,
#  'rim offset inside': 9,
#  'phiale': 9,
#  'convex wall': 9,
#  'convex and large': 9,
#  'rolled rim': 9,
#  'large versions and related shapes': 9,
#  'tub': 9,
#  'attic and various': 9,
#  'plain wall': 8,
#  'one handle': 8,
#  'rheneia cup': 8,
#  'shallow': 8,
#  'early and heavy': 8,
#  'broad base': 8,
#  'black and plain': 8,
#  'relief top fragments': 8,
#  'late trefoil': 8,
#  'early varieties to ca. 525 b.c.': 8,
#  'lidded pelike and lid': 7,
#  'two-handled': 7,
#  'south': 7,
#  'strainer': 7,
#  'sessile with low handles': 7,
#  'one-handled': 7,
#  'deep wall and convex-concave profile': 7,
#  'shallow wall and convex-concave profile': 7,
#  'plate and saucer': 7,
#  'small and late': 7,
#  'lidless': 7,
#  'ring': 7,
#  'other vessels for wine service': 6,
#  'ring-collar': 6,
#  'offset neck and trefoil mouth': 6,
#  'shape 1': 6,
#  'round mouth': 6,
#  'high or low handle': 6,
#  'votives and other vessels for religious use': 6,
#  'bevelled foot': 6,
#  'kantharos: special handles': 6,
#  'chalice shape': 6,
#  'kyathos': 6,
#  'black-bodied': 6,
#  'vertical ribs': 6,
#  'disc': 6,
#  'midget': 6,
#  'small storage amphora': 6,
#  'storage amphora': 6,
#  'small pithos': 6,
#  'heavy round-topped rim': 6,
#  'column-krater': 5,
#  'vessels for pouring and dipping': 5,
#  'chous (oinochoe, shape 3)': 5,
#  'acrocup': 5,
#  'east': 5,
#  'stoa of attalos': 5,
#  'excavation and study': 5,
#  'black glazed': 5,
#  'squat rim': 5,
#  'classical type': 5,
#  'calyx-cup': 5,
#  'echinus bowl': 5,
#  'steep wall': 5,
#  'pyre type': 5,
#  'vessels for oil': 5,
#  'stamped fragments': 5,
#  'dumped filling, ca 500 b.c.': 5,
#  'perfume-pot': 5,
#  'lykinic': 5,
#  'kothon': 5,
#  'low': 5,
#  'imported side-handled and related': 5,
#  'ribbon-handled plate': 5,
#  'epinetron': 5,
#  'funnel': 5,
#  'neck-amphora': 4,
#  'one-piece amphora and various': 4,
#  'bell-krater': 4,
#  'canted handles': 4,
#  'vicup': 4,
#  'class of agora p 10359': 4,
#  'inset lip': 4,
#  'later versions': 4,
#  'rim plain or offset': 4,
#  'sessile with high handles': 4,
#  'sotadean': 4,
#  'plate: rolled rim': 4,
#  'kitchen shapes': 4,
#  'amphoriskos and unguentarium': 4,
#  'saucer': 4,
#  'late variants': 4,
#  'pithos ware': 4,
#  'various': 4,
#  'sandy class': 4,
#  'fabrics other than corinthian': 4,
#  'cylindrical stand or brazier': 4,
#  'bottom fill: late 6th c. b.c., at latest.': 3,
#  'lid': 3,
#  'lebes': 3,
#  'shoulder oinochoe': 3,
#  'shape 2': 3,
#  'round-mouth': 3,
#  'shape 9': 3,
#  'horizontal ribs': 3,
#  'small ritual vessels': 3,
#  'band cup': 3,
#  'fragments of feet': 3,
#  '6th century shapes': 3,
#  'miscellaneous 5th century shapes': 3,
#  'globular': 3,
#  'bowl-shaped': 3,
#  'knotted handles': 3,
#  'strap handles, turned foot': 3,
#  'shallow: classical type': 3,
#  'projecting rim': 3,
#  'elongated body': 3,
#  'unguent-pot': 3,
#  'strainer top': 3,
#  'guttus type': 3,
#  'cup-handled': 3,
#  'bare-bottom class': 3,
#  'miscellaneous small lids': 3,
#  'vessels from ritual pyres': 3,
#  'powder pyxis': 3,
#  'miscellaneous lids': 3,
#  'stand': 3,
#  'lopadion': 3,
#  'attic narrow-necked': 3,
#  'medicine-pot': 3,
#  'banded and plain pelike': 2,
#  'lebes gamikos': 2,
#  'variant': 2,
#  'homer thompson': 2,
#  'wells': 2,
#  '"buckets", "old oaren; b.h.w.j.': 2,
#  'black variants': 2,
#  'shape 5': 2,
#  'black-glazed votive skyphos': 2,
#  'residential-industrial area to west and south of the areopagus': 2,
#  'siana cup': 2,
#  'cracow class and related': 2,
#  'concave rim': 2,
#  'pointed body': 2,
#  'bowl-kantharos': 2,
#  'classical kantharos': 2,
#  'goblet': 2,
#  'bowl: outturned rim': 2,
#  'central': 2,
#  'regular size': 2,
#  'flat foot': 2,
#  'tray': 2,
#  'lidded': 2,
#  'feeder': 2,
#  'bell': 2,
#  'small plate': 2,
#  'duck askos': 2,
#  'unglazed': 2,
#  'handles rising from rim': 2,
#  'oddities': 2,
#  '?': 2,
#  'dipper': 2,
#  'amis': 2,
#  'torch or taper stand': 2,
#  'cooking-bell': 2,
#  'grill': 2,
#  'neck-pelike': 1,
#  'pitharion': 1,
#  'fragment': 1,
#  'serving vessels': 1,
#  'spouted bowl': 1,
#  'thickened rim': 1,
#  'low handle': 1,
#  'droop cup': 1,
#  'molded rim': 1,
#  'filleted stem': 1,
#  'special handles': 1,
#  'conical': 1,
#  'sanctuary of the twelve gods': 1,
#  'medium': 1,
#  'dourian': 1,
#  'shoulder lekythos': 1,
#  'areopagus slopes': 1,
#  'areopagus north slope': 1,
#  'greek houses': 1,
#  'southeast unit': 1,
#  '6th century class': 1,
#  'guttus': 1,
#  'west': 1,
#  'pyre lekanis': 1,
#  'tripod-pyxis': 1,
#  'egg': 1,
#  'kernos': 1,
#  'miniature votives': 1,
#  'krateriskos': 1,
#  'unguentarium': 1,
#  '6th and 7th centuries b.c.': 1,
#  'special shape': 1,
#  'iv. top to -7.25m': 1,
#  'water works': 1,
#  'latrines': 1,
#  'house of simon the cobbler': 1,
#  'walls': 1,
#  'post-herulian wall': 1,
#  'invalid cup': 1,
#  'tripod': 1,
#  'barrel-cooker': 1,
#  'oven': 1}

# %%
frequencyBars(classificationClasses, "Classifications", 1)
# Out:
# 286 more Classifications with frequency <= 1%

# %%
classClasses = uniqueClassFreq('Class')
classClasses
# Out:
# {'black and plain pottery': 2000,
#  'kantharos': 124,
#  'small bowl and saltcellar': 114,
#  'oinochoe': 110,
#  'lekane': 105,
#  'plate': 95,
#  'jug': 86,
#  'skyphos': 79,
#  'imported': 77,
#  'stemless': 72,
#  'miniature': 72,
#  'lekanis': 69,
#  'saltcellar': 67,
#  'cup': 66,
#  'bowl': 66,
#  'amphora and amphoriskos': 65,
#  'cup-skyphos': 61,
#  'one-handler': 59,
#  'small': 57,
#  'plain rim': 56,
#  'olpe': 54,
#  'lekythos': 50,
#  'large': 49,
#  'small bowl': 47,
#  'askos': 45,
#  'mug': 44,
#  'black': 42,
#  'main sequence': 40,
#  'ca. 525-ca. 300 b.c.': 40,
#  'type c': 39,
#  'cup-kantharos': 39,
#  'stemmed dish': 39,
#  'mortar': 38,
#  'chytra': 37,
#  'attic': 36,
#  'delicate class': 35,
#  'chous': 34,
#  'shape 3': 34,
#  'variants': 34,
#  'pyxis': 34,
#  'light wall': 32,
#  'outturned rim': 32,
#  'bolsal': 30,
#  'louterion': 30,
#  'decorated basin and stand fragments': 30,
#  'table amphora': 29,
#  'moulded rim': 28,
#  'banded': 27,
#  'corinthian type': 27,
#  'fragments used as ostraka': 27,
#  'attic variants and imported plain': 26,
#  'hydria': 25,
#  'type a': 25,
#  'various fabrics': 25,
#  'cooking devices': 25,
#  '6th and 5th century shapes': 24,
#  'rilled rim': 24,
#  'lopas': 24,
#  'standard': 23,
#  'narrow-necked': 23,
#  'miscellaneous household utensils': 23,
#  'pheidias shape': 22,
#  'echinus wall': 22,
#  'squat lekythos': 22,
#  'tile fabrics': 22,
#  'pelike': 21,
#  'large bowl': 21,
#  'attic type': 21,
#  'pithos': 21,
#  'household ware': 21,
#  'footed': 20,
#  'concave lip': 20,
#  'convex and small': 20,
#  'storage-bin': 20,
#  'banded round-mouth': 19,
#  '6th century types': 19,
#  'patterned': 19,
#  'thurible': 19,
#  'trefoil cooking ware and related': 19,
#  'corinthian': 19,
#  'common type': 19,
#  'subgeometric survivals': 18,
#  'early': 18,
#  '6th century and early 5th': 18,
#  'incurving rim': 18,
#  'concave wall': 18,
#  'votive': 18,
#  'wide-mouthed and lidded': 18,
#  'amphora': 17,
#  'decoration and undersides': 17,
#  'type d': 17,
#  'attic and imported': 17,
#  'vases from sacrificial pyres': 17,
#  'fish-plate': 16,
#  'miscellaneous shapes': 16,
#  'miscellaneous': 15,
#  'broad rim': 15,
#  'rolled rim': 15,
#  'black deianeira': 15,
#  'covered bowl': 15,
#  'household lekanis': 15,
#  'kados': 15,
#  'wide-mouthed': 15,
#  'thickened': 15,
#  'rounded or outcurved rim': 15,
#  'mushroom jug': 14,
#  'footless': 14,
#  'deep': 14,
#  'later and light': 14,
#  'lids for ribbon-handled lekanides or variants': 14,
#  'stemmed': 14,
#  'cooking ware': 14,
#  'gray ware': 14,
#  'handles turned up to rim': 14,
#  'griddle': 14,
#  'bean-parcher': 14,
#  'miscellaneous round-mouth': 13,
#  'kalathos': 13,
#  'amphoriskos': 13,
#  'table and storage amphora': 13,
#  'collar rim': 13,
#  'eschara': 13,
#  'globular body': 12,
#  'black and plain': 12,
#  'stamped class': 12,
#  'impressed or incised decoration': 12,
#  'ladle': 12,
#  'lidless pelike': 11,
#  'trefoil': 11,
#  'heavy wall': 11,
#  'thickened edge': 11,
#  'lidded with ribbon handles': 11,
#  'various shapes': 11,
#  'small or medium-sized versions': 11,
#  'normal version': 11,
#  'tall-necked': 11,
#  'attic and various': 11,
#  'psykter': 10,
#  'krater': 10,
#  'type b': 10,
#  'rim offset inside': 10,
#  'late trefoil': 10,
#  'tub': 10,
#  'class of athens 1104': 9,
#  'phiale': 9,
#  'shallow wall and convex-concave profile': 9,
#  'early and heavy': 9,
#  'convex wall': 9,
#  'convex and large': 9,
#  'small pithos': 9,
#  'large versions and related shapes': 9,
#  'early varieties to ca. 525 b.c.': 9,
#  'plain wall': 8,
#  'one handle': 8,
#  'rheneia cup': 8,
#  'broad base': 8,
#  'relief top fragments': 8,
#  'lidded pelike and lid': 7,
#  'two-handled': 7,
#  'round mouth': 7,
#  'high or low handle': 7,
#  'strainer': 7,
#  'sessile with low handles': 7,
#  'one-handled': 7,
#  'special handles': 7,
#  'deep wall and convex-concave profile': 7,
#  'small and late': 7,
#  'lidless': 7,
#  'ring': 7,
#  'ring-collar': 6,
#  'offset neck and trefoil mouth': 6,
#  'shape 1': 6,
#  'bevelled foot': 6,
#  'chalice shape': 6,
#  'kyathos': 6,
#  'pyre type': 6,
#  'black-bodied': 6,
#  'vertical ribs': 6,
#  'shallow': 6,
#  'disc': 6,
#  'kothon': 6,
#  'midget': 6,
#  'small storage amphora': 6,
#  'storage amphora': 6,
#  'heavy round-topped rim': 6,
#  'one-piece amphora and various': 5,
#  'column-krater': 5,
#  'vicup': 5,
#  'acrocup': 5,
#  'inset lip': 5,
#  'later versions': 5,
#  'rim plain or offset': 5,
#  'sotadean': 5,
#  'squat rim': 5,
#  'bowl-shaped': 5,
#  'calyx-cup': 5,
#  'steep wall': 5,
#  'stamped fragments': 5,
#  'guttus type': 5,
#  'perfume-pot': 5,
#  'lykinic': 5,
#  'low': 5,
#  'imported side-handled and related': 5,
#  'amphoriskos and unguentarium': 5,
#  'ribbon-handled plate': 5,
#  'epinetron': 5,
#  'funnel': 5,
#  'neck-amphora': 4,
#  'bell-krater': 4,
#  'canted handles': 4,
#  'class of agora p 10359': 4,
#  'sessile with high handles': 4,
#  'unguent-pot': 4,
#  'kitchen shapes': 4,
#  'saucer': 4,
#  'late variants': 4,
#  'pithos ware': 4,
#  'various': 4,
#  'sandy class': 4,
#  'fabrics other than corinthian': 4,
#  'medicine-pot': 4,
#  'cylindrical stand or brazier': 4,
#  'lid': 3,
#  'lebes': 3,
#  'shoulder oinochoe': 3,
#  'shape 2': 3,
#  'round-mouth': 3,
#  'shape 9': 3,
#  'horizontal ribs': 3,
#  'band cup': 3,
#  'fragments of feet': 3,
#  'concave rim': 3,
#  '6th century shapes': 3,
#  'miscellaneous 5th century shapes': 3,
#  'globular': 3,
#  'projecting rim': 3,
#  'elongated body': 3,
#  'strainer top': 3,
#  'cup-handled': 3,
#  'bare-bottom class': 3,
#  'miscellaneous small lids': 3,
#  'powder pyxis': 3,
#  'miscellaneous lids': 3,
#  'stand': 3,
#  'lopadion': 3,
#  'small plate': 3,
#  'attic narrow-necked': 3,
#  'handles rising from rim': 3,
#  'banded and plain pelike': 2,
#  'lebes gamikos': 2,
#  'black variants': 2,
#  'shape 5': 2,
#  'siana cup': 2,
#  'cracow class and related': 2,
#  'pointed body': 2,
#  'goblet': 2,
#  'flat foot': 2,
#  'tray': 2,
#  'lidded': 2,
#  'feeder': 2,
#  'reversible lids': 2,
#  'bell': 2,
#  'special shape': 2,
#  'oddities': 2,
#  '?': 2,
#  'dipper': 2,
#  'amis': 2,
#  'torch or taper stand': 2,
#  'cooking-bell': 2,
#  'grill': 2,
#  'oven': 2,
#  'neck-pelike': 1,
#  'pitharion': 1,
#  'fragment': 1,
#  'spouted bowl': 1,
#  'thickened rim': 1,
#  'low handle': 1,
#  'droop cup': 1,
#  'type a 1': 1,
#  'filleted stem': 1,
#  'conical': 1,
#  'dourian': 1,
#  'shoulder lekythos': 1,
#  '6th century class': 1,
#  'tripod-pyxis': 1,
#  'egg': 1,
#  'kernos': 1,
#  'invalid cup': 1,
#  'tripod': 1,
#  'barrel-cooker': 1}

# %%
frequencyBars(classClasses, "Classes", 1)
# Out:
# 220 more Classes with frequency <= 1%

# %% [markdown]
# ### Fields: "Chronology" & "ChronologyRange"

# %%
data[['Chronology', 'ChronologyRange']].head()
# Out:
#          Chronology ChronologyRange
# 0      575-550 B.C.       -575;-550
# 1  Late 6th c. B.C.       -525;-500
# 2      Ca. 500 B.C.            -500
# 3      Ca. 500 B.C.            -500
# 4  Late 6th c. B.C.       -525;-500

# %% [markdown]
# Instead of dropping records with missing chronology, add flag column that indicates the record's validity based on its chronology, so that for
# - Chronology Prediction: records with non-valid chronology are filtered out
# -  Similarity Search: all records are used (not dependent on chronology labels)

# %%
# data = data.dropna(subset=['ChronologyRange']).copy()

data["ValidChronology"] = True
data.loc[data["ChronologyRange"].isna(), "ValidChronology"] = False
data[['ChronologyRange', 'ValidChronology']].head()
# Out:
#   ChronologyRange  ValidChronology
# 0       -575;-550             True
# 1       -525;-500             True
# 2            -500             True
# 3            -500             True
# 4       -525;-500             True

# %%
valid_rows = data["ValidChronology"]

# %%
print(f'Initial Dataset Shape:\t\t\t{data.shape}')
print(f'Valid Chronology Dataset Shape:\t{data[valid_rows].shape}')
# Out:
# Initial Dataset Shape:			(2000, 22)
# Valid Chronology Dataset Shape:	(1990, 22)

# %% [markdown]
# #### Split ChronologyRange to StartYear and EndYear Columns

# %% [markdown]
# Only split non-null ChronologyRange values

# %%
split_columns = data.loc[valid_rows, 'ChronologyRange'].str.split(';', expand=True)
split_columns
# Out:
#          0     1
# 0     -575  -550
# 1     -525  -500
# 2     -500  None
# 3     -500  None
# 4     -525  -500
# ...    ...   ...
# 1995  -350  -320
# 1996  -350  -301
# 1997  -435  -425
# 1998  -375  -325
# 1999  -400  -300
#
# [1990 rows x 2 columns]

# %% [markdown]
# Assign StartYear and EndYear, but only where ChronologyRange is not null

# %%
data.loc[split_columns.index, 'StartYear'] = split_columns[0]
data.loc[split_columns.index, 'EndYear'] = split_columns[1]

# %% [markdown]
# Fill EndYear with StartYear if missing (only for non-null ChronologyRange)

# %%
data.loc[split_columns.index, "EndYear"] = data.loc[split_columns.index, "EndYear"].fillna(
    data.loc[split_columns.index, "StartYear"])

# %% [markdown]
# Convert to numeric safely (ignore NaNs)

# %%
data['StartYear'] = pd.to_numeric(data['StartYear'], errors='coerce').astype('Int64')
data['EndYear'] = pd.to_numeric(data['EndYear'], errors='coerce').astype('Int64')

# %%
data[['ChronologyRange', 'StartYear', 'EndYear', 'ValidChronology']]
# Out:
#      ChronologyRange  StartYear  EndYear  ValidChronology
# 0          -575;-550       -575     -550             True
# 1          -525;-500       -525     -500             True
# 2               -500       -500     -500             True
# 3               -500       -500     -500             True
# 4          -525;-500       -525     -500             True
# ...              ...        ...      ...              ...
# 1995       -350;-320       -350     -320             True
# 1996       -350;-301       -350     -301             True
# 1997       -435;-425       -435     -425             True
# 1998       -375;-325       -375     -325             True
# 1999       -400;-300       -400     -300             True
#
# [2000 rows x 4 columns]

# %% [markdown]
# #### Define Historical Periods

# %%
periods = [
    ("Geometric", -900, -700),
    ("Orientalizing", -700, -600),
    ("Archaic", -600, -480),
    ("Classical", -480, -323),
    ("Hellenistic", -323, -31),
    ("Roman", -31, 330),
    ("Late Roman / Early Byzantine", 330, 700)
]

period_colors = {
    "Geometric": PAL_DEFAULT[8],
    "Orientalizing": PAL_DEFAULT[6],
    "Archaic": PAL_DEFAULT[0],
    "Classical": PAL_DEFAULT[2],
    "Hellenistic": PAL_DEFAULT[4],
    "Roman": PAL_DEFAULT[3],
    "Late Roman / Early Byzantine": PAL_DEFAULT[5],
}

# %% [markdown]
# #### Plot Timeline

# %%
def plot_timeline():
    # Sort data
    data_sorted = data[data["ValidChronology"]].sort_values(by=['StartYear']).reset_index(drop=True)
    start = data_sorted['StartYear'].to_numpy(float)
    end = data_sorted['EndYear'].to_numpy(float)

    # single-year records would be invisible as zero-length segments
    end_vis = np.where(end == start, end + 1, end)

    with sns.axes_style("darkgrid", {"grid.color": "white", "axes.edgecolor": "white"}):
        fig, ax = plt.subplots(figsize=(26, 18))
        pad = 10
        x_min, x_max = start.min() - pad, end.max() + pad

        # Period spans
        for name, lower_limit, upper_limit in periods:
            if lower_limit < end.max() and upper_limit > start.min():  # overlaps the data range
                span_start = x_min if lower_limit <= start.min() else lower_limit
                span_end = x_max if upper_limit >= end.max() else upper_limit
                ax.axvspan(span_start, span_end, color=period_colors[name], alpha=0.15, lw=0)
                if span_start == lower_limit: ax.axvline(span_start, color="white", lw=3, alpha=1)
                ax.text(span_start, 1.005, name, transform=ax.get_xaxis_transform(), ha='left', fontsize=16)

        # Chronology range lines
        ax.hlines(np.arange(len(data_sorted)), start, end_vis, lw=1.1)

        ax.set_xlim(x_min, x_max)
        ax.set_ylim(len(data_sorted) + 50, -50)  # reversed: earliest records at the top / with 50 unit padding
        ax.xaxis.set_major_locator(plt.MultipleLocator(50))
        ax.tick_params(axis='x', labelsize=16)
        ax.set_yticks([])
        ax.set_xlabel("Years", fontsize=16)
        ax.set_ylabel("Pottery Records", fontsize=16)
        plt.tight_layout()
        plt.show()

# %%
plot_timeline()

# %% [markdown]
# #### Assign Historical Periods
#
# get all the periods that the current record's start to end year overlaps and from these decide which one to assign, by determining in which the longest range of the record's chronology falls in. for example:
# 1. start_year = -520 , end_year = -500 --> clearly in archaic period
# 2. start_year = -490 , end_year = -450 --> overlaps both archaic and classical, but has 30 years in classical and only 10 in archaic, therefore choose classical

# %%
# assign period based on maximum overlap
def assign_period(start_year, end_year):
    # Special case: if it's a single year (point)
    if start_year == end_year:
        for name, p_start, p_end in periods:
            if p_start <= start_year <= p_end:
                return name

    # Normal case: interval (range)
    max_overlap = 0
    best_period = ""

    for name, p_start, p_end in periods:
        # Find overlap interval
        overlap_start = max(start_year, p_start)
        overlap_end = min(end_year, p_end)

        # Calculate overlap length (if any)
        if overlap_start <= overlap_end:
            overlap = overlap_end - overlap_start
            if overlap > max_overlap:
                max_overlap = overlap
                best_period = name

    return best_period

# %%
data.loc[valid_rows, "HistoricalPeriod"] = data.loc[valid_rows].apply(
    lambda row: assign_period(row["StartYear"], row["EndYear"]),
    axis=1
)

# %%
data[["StartYear", "EndYear", "HistoricalPeriod"]].head(20)
# Out:
#     StartYear  EndYear HistoricalPeriod
# 0        -575     -550          Archaic
# 1        -525     -500          Archaic
# 2        -500     -500          Archaic
# 3        -500     -500          Archaic
# 4        -525     -500          Archaic
# 5        -525     -500          Archaic
# 6        -525     -500          Archaic
# 7        -480     -450        Classical
# 8        -482     -482          Archaic
# 9        -500     -500          Archaic
# 10       -480     -450        Classical
# 11       -400     -300        Classical
# 12       -525     -525          Archaic
# 13       -525     -500          Archaic
# 14       -500     -500          Archaic
# 15       -500     -500          Archaic
# 16       -500     -490          Archaic
# 17       -500     -490          Archaic
# 18       -500     -480          Archaic
# 19       -500     -480          Archaic

# %%
data.loc[valid_rows, "HistoricalPeriod"].unique()
# Out:
# array(['Archaic', 'Classical', 'Hellenistic', 'Orientalizing', 'Roman'],
#       dtype=object)

# %%
def plot_period_distribution():
    present = set(data.loc[valid_rows, "HistoricalPeriod"])
    period_order = [name for name, _, _ in periods if name in present]

    plt.figure(figsize=(12, 6))
    sns.countplot(data=data.loc[valid_rows], y="HistoricalPeriod", order=period_order,
                  hue="HistoricalPeriod", palette=period_colors, legend=False)

    # Titles and labels
    plt.title("Distribution of Pottery Records by Historical Period", fontsize=16)
    plt.xlabel("Number of Records", fontsize=14)
    plt.ylabel("Historical Period", fontsize=14)

    for i, v in enumerate(data.loc[valid_rows, "HistoricalPeriod"].value_counts().reindex(period_order)):
        plt.text(v + 2, i, f"{round(100 * v / data.loc[valid_rows].shape[0], 2)}%", color='black', va='center',
                 fontweight='bold')

    plt.show()

# %%
plot_period_distribution()

# %% [markdown]
# #### Midpoint Year

# %%
data.loc[valid_rows, "MidpointYear"] = (data.loc[valid_rows, "StartYear"] + data.loc[valid_rows, "EndYear"]) / 2
data[['StartYear', 'EndYear', 'MidpointYear']].head()
# Out:
#    StartYear  EndYear  MidpointYear
# 0       -575     -550        -562.5
# 1       -525     -500        -512.5
# 2       -500     -500        -500.0
# 3       -500     -500        -500.0
# 4       -525     -500        -512.5

# %% [markdown]
# #### Year Range

# %%
data.loc[valid_rows, "YearRange"] = data.loc[valid_rows, "EndYear"] - data.loc[valid_rows, "StartYear"]
data['YearRange'] = pd.to_numeric(data['YearRange'], errors='coerce').astype('Int64')
data[['StartYear', 'EndYear', 'YearRange']].head()
# Out:
#    StartYear  EndYear  YearRange
# 0       -575     -550         25
# 1       -525     -500         25
# 2       -500     -500          0
# 3       -500     -500          0
# 4       -525     -500         25

# %%
data.loc[data['YearRange'] > 50].shape[0]
# Out:
# 80

# %%
test = np.sort(data.loc[valid_rows, "YearRange"].unique())
test
# Out:
# array([  0,   9,  10,  15,  20,  24,  25,  30,  35,  40,  45,  49,  50,
#         55,  60,  74,  75,  80,  99, 100, 200, 220, 275, 740, 940])

# %%
def plot_year_range_distribution():
    year_ranges = data.loc[valid_rows, "YearRange"]

    bins = [-1]
    for i in range(0, 101, 10):
        bins.append(i)
        if i >= year_ranges.max():
            break
    if year_ranges.max() > 100:
        bins.append(1000)

    labels = ["0"]
    for i, j in pairwise(bins[1:]):
        labels.append(f"({i}, {j}]")

    # Create a new binned column
    year_range_bins = pd.cut(year_ranges, bins=bins, labels=labels, right=True)

    # Plot
    bin_counts = year_range_bins.value_counts().sort_index()

    plt.figure(figsize=(16, 8))
    plt.bar(bin_counts.index, bin_counts.values)
    plt.xlabel("Year Range Interval")
    plt.ylabel("Number of Records")
    plt.title("Distribution of Year Range Intervals")
    plt.grid(True)
    plt.show()

# %%
plot_year_range_distribution()

# %% [markdown]
# #### Quality Filtering
#
# Refine ValidChronology flag based on YearRange
#
# If YearRange > 50 → set ValidChronology to False

# %%
data["ValidChronology"] = True
data.loc[data["ChronologyRange"].isna(), "ValidChronology"] = False
data.loc[data["YearRange"] > 50, "ValidChronology"] = False

valid_rows = data["ValidChronology"]

# %%
data["ValidChronology"].sum()
# Out:
# np.int64(1910)

# %%
plot_timeline()

# %%
plot_year_range_distribution()

# %%
plot_period_distribution()

# %% [markdown]
# ### Images

# %% [markdown]
# #### Image Stats Before Download
#
# Track image availability for both the full dataset (**unfiltered**) and the valid-chronology subset (**filtered**).

# %%
# tabulate counts as (unfiltered | filtered) x (count, % of total, % of previous)
def image_stats_table(stats):
    cols = {}
    for subset in ("unfiltered", "filtered"):
        counts = [v[subset] for v in stats.values()]
        total = counts[0]
        cols[(subset, "count")] = counts
        cols[(subset, "% of total")] = [f"{c / total:.1%}" for c in counts]
        cols[(subset, "% of previous")] = ["-"] + [
            f"{c / p:.1%}" for p, c in zip(counts, counts[1:])
        ]
    return pd.DataFrame(cols, index=list(stats.keys()))

# %% [markdown]
# Check media-link availability, before downloading:

# %%
data_states = {
    "unfiltered": data,
    "filtered": data.loc[data["ValidChronology"]],
}

image_stats = {
    "total_records": {
        state: len(records)
        for state, records in data_states.items()
    },
    "media_link_in_Parent": {
        state: int(records["Parent"].notna().sum())
        for state, records in data_states.items()
    },
    "image_type_link": {
        state: int(records["Parent"].str.contains("Agora:Image", na=False).sum())
        for state, records in data_states.items()
    },
}

display(image_stats_table(image_stats))
# Out:
#                      unfiltered                          filtered             \
#                           count % of total % of previous    count % of total
# total_records              2000     100.0%             -     1910     100.0%
# media_link_in_Parent       1366      68.3%         68.3%     1315      68.8%
# image_type_link            1047      52.3%         76.6%     1011      52.9%
#
#
#                      % of previous
# total_records                    -
# media_link_in_Parent         68.8%
# image_type_link              76.9%

# %% [markdown]
# #### Download Images

# %%
imageUrl = "https://ascsa.net/image"
imageDir = path + "images"

os.makedirs(imageDir, exist_ok=True)

# %%
# Function to download images
def downloadImage(imageID, imageType="full"):
    # Escape colons to match URL format
    escImageID = quote(imageID, safe='')

    # Construct the download URL
    url = f"{imageUrl}?type={imageType}&id={escImageID}"

    # Define the image's path
    imageFilename = imageID.replace(":", "_") + ".jpg"
    imagePath = os.path.join(imageDir, imageFilename)

    # Check if the file already exists and is valid
    if os.path.isfile(imagePath) and os.path.getsize(imagePath) > 0:
        print(f"✅ File exists and is valid: {imageFilename}")
        return imageFilename

    try:
        # Send HTTP request
        response = requests.get(url, stream=True)
        response.raise_for_status()  # Raise error if request fails

        # Save image
        with open(imagePath, "wb") as file:
            for chunk in response.iter_content(1024):
                file.write(chunk)

        print(f"✅ Downloaded: {imageFilename}")
        return imageFilename

    except requests.RequestException as e:
        print(f"❌ Failed to download {imageID}: {e}")
        return None

# %%
# download one image per record with an image-type media link
for index, record in data.iterrows():
    imageID = record["Parent"]

    if type(imageID) != str:
        continue
    if not imageID.startswith("Agora:Image"):
        continue

    downloadedFilename = downloadImage(imageID)

    if downloadedFilename:
        data.loc[index, "ImageFilename"] = downloadedFilename
# Out:
# ✅ File exists and is valid: Agora_Image_2012.54.1450.jpg
# ✅ File exists and is valid: Agora_Image_2012.27.0009.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0468.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0468.jpg
# ✅ File exists and is valid: Agora_Image_2012.54.1467.jpg
# ✅ File exists and is valid: Agora_Image_2000.06.0201.jpg
# ✅ File exists and is valid: Agora_Image_2017.03.0408.jpg
# ✅ File exists and is valid: Agora_Image_2012.50.0871.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0518.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0518.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0518.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0467.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0467.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0467.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0048.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0048.jpg
# ❌ Failed to download Agora:Image:2014.01.0113: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2014.01.0113
# ✅ File exists and is valid: Agora_Image_2012.56.0134.jpg
# ✅ File exists and is valid: Agora_Image_2012.51.0790.jpg
# ❌ Failed to download Agora:Image:2014.01.0113: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2014.01.0113
# ✅ File exists and is valid: Agora_Image_2012.51.0790.jpg
# ❌ Failed to download Agora:Image:2014.01.0113: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2014.01.0113
# ✅ File exists and is valid: Agora_Image_2012.56.0466.jpg
# ❌ Failed to download Agora:Image:2017.06.0467: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2017.06.0467
# ✅ File exists and is valid: Agora_Image_2012.56.0466.jpg
# ✅ File exists and is valid: Agora_Image_2012.50.0110.jpg
# ❌ Failed to download Agora:Image:2015.06.1286: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2015.06.1286
# ✅ File exists and is valid: Agora_Image_2012.74.0840.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.0648.jpg
# ✅ File exists and is valid: Agora_Image_2013.04.9236.jpg
# ✅ File exists and is valid: Agora_Image_2019.04.0455.jpg
# ✅ File exists and is valid: Agora_Image_2016.04.0618.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0548.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0548.jpg
# ✅ File exists and is valid: Agora_Image_2012.23.0078.jpg
# ✅ File exists and is valid: Agora_Image_2019.03.0415.jpg
# ✅ File exists and is valid: Agora_Image_2012.54.1467.jpg
# ✅ File exists and is valid: Agora_Image_2012.26.0156.jpg
# ✅ File exists and is valid: Agora_Image_2012.59.0549.jpg
# ✅ File exists and is valid: Agora_Image_2017.03.0423.jpg
# ✅ File exists and is valid: Agora_Image_2012.54.1467.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1442.jpg
# ❌ Failed to download Agora:Image:2014.01.0113: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2014.01.0113
# ✅ File exists and is valid: Agora_Image_2012.60.0322.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.0964.jpg
# ✅ File exists and is valid: Agora_Image_2022.03.0659.jpg
# ❌ Failed to download Agora:Image:2012.22.0194: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.22.0194
# ✅ File exists and is valid: Agora_Image_2012.02.7150.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.0434.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.0964.jpg
# ✅ File exists and is valid: Agora_Image_2012.60.0314.jpg
# ✅ File exists and is valid: Agora_Image_2012.23.0079.jpg
# ✅ File exists and is valid: Agora_Image_2012.54.1450.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1442.jpg
# ✅ File exists and is valid: Agora_Image_2012.60.0316.jpg
# ✅ File exists and is valid: Agora_Image_2004.01.1113.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.0423.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.0423.jpg
# ✅ File exists and is valid: Agora_Image_2012.78.1142.jpg
# ✅ File exists and is valid: Agora_Image_2012.52.0554.jpg
# ✅ File exists and is valid: Agora_Image_2012.52.0554.jpg
# ✅ File exists and is valid: Agora_Image_2016.04.0043.jpg
# ❌ Failed to download Agora:Image:2014.01.0113: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2014.01.0113
# ✅ File exists and is valid: Agora_Image_2012.52.0554.jpg
# ✅ File exists and is valid: Agora_Image_2012.85.0533.jpg
# ✅ File exists and is valid: Agora_Image_2012.85.0534.jpg
# ✅ File exists and is valid: Agora_Image_2012.02.7187.jpg
# ✅ File exists and is valid: Agora_Image_2012.78.0626.jpg
# ✅ File exists and is valid: Agora_Image_2012.78.0624.jpg
# ✅ File exists and is valid: Agora_Image_2012.25.0114.jpg
# ✅ File exists and is valid: Agora_Image_2012.51.0796.jpg
# ✅ File exists and is valid: Agora_Image_2012.51.0796.jpg
# ✅ File exists and is valid: Agora_Image_2012.24.0062.jpg
# ✅ File exists and is valid: Agora_Image_2012.24.0062.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.0927.jpg
# ✅ File exists and is valid: Agora_Image_2012.22.0137.jpg
# ✅ File exists and is valid: Agora_Image_2012.22.0137.jpg
# ✅ File exists and is valid: Agora_Image_2012.22.0137.jpg
# ✅ File exists and is valid: Agora_Image_2012.76.1508.jpg
# ✅ File exists and is valid: Agora_Image_2012.02.7140.jpg
# ✅ File exists and is valid: Agora_Image_2012.76.1509.jpg
# ✅ File exists and is valid: Agora_Image_2012.76.1516.jpg
# ✅ File exists and is valid: Agora_Image_2012.76.1524.jpg
# ✅ File exists and is valid: Agora_Image_2012.76.1504.jpg
# ✅ File exists and is valid: Agora_Image_2019.03.0423.jpg
# ✅ File exists and is valid: Agora_Image_2019.03.0432.jpg
# ✅ File exists and is valid: Agora_Image_2019.03.0441.jpg
# ✅ File exists and is valid: Agora_Image_2012.54.1448.jpg
# ✅ File exists and is valid: Agora_Image_2014.04.0651.jpg
# ✅ File exists and is valid: Agora_Image_2012.02.4394.jpg
# ✅ File exists and is valid: Agora_Image_2017.03.0413.jpg
# ✅ File exists and is valid: Agora_Image_2022.03.0774.jpg
# ✅ File exists and is valid: Agora_Image_2012.53.0870.jpg
# ✅ File exists and is valid: Agora_Image_2012.54.1448.jpg
# ✅ File exists and is valid: Agora_Image_2012.26.0315.jpg
# ✅ File exists and is valid: Agora_Image_2012.51.1099.jpg
# ✅ File exists and is valid: Agora_Image_2000.02.0313.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1472.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1472.jpg
# ✅ File exists and is valid: Agora_Image_2013.04.0026.jpg
# ✅ File exists and is valid: Agora_Image_2013.04.0055.jpg
# ✅ File exists and is valid: Agora_Image_2013.04.0058.jpg
# ✅ File exists and is valid: Agora_Image_2014.01.0023.jpg
# ✅ File exists and is valid: Agora_Image_2014.01.0024.jpg
# ✅ File exists and is valid: Agora_Image_2013.04.0003.jpg
# ✅ File exists and is valid: Agora_Image_2013.04.0018.jpg
# ✅ File exists and is valid: Agora_Image_2013.04.0038.jpg
# ✅ File exists and is valid: Agora_Image_2013.04.0032.jpg
# ✅ File exists and is valid: Agora_Image_2013.04.0035.jpg
# ❌ Failed to download Agora:Image:2013.04.0029: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2013.04.0029
# ✅ File exists and is valid: Agora_Image_2012.54.1449.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.0427.jpg
# ✅ File exists and is valid: Agora_Image_2012.50.0304.jpg
# ✅ File exists and is valid: Agora_Image_2012.25.0100.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.0649.jpg
# ✅ File exists and is valid: Agora_Image_2012.76.0329.jpg
# ✅ File exists and is valid: Agora_Image_2012.02.7197.jpg
# ❌ Failed to download Agora:Image:2014.01.0113: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2014.01.0113
# ✅ File exists and is valid: Agora_Image_2012.55.1476.jpg
# ✅ File exists and is valid: Agora_Image_2007.04.0015.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.0427.jpg
# ✅ File exists and is valid: Agora_Image_2013.09.0006.jpg
# ✅ File exists and is valid: Agora_Image_2012.25.0348.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0046.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0046.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1486.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1486.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1473.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1473.jpg
# ✅ File exists and is valid: Agora_Image_2012.60.0316.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1473.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1474.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1474.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1474.jpg
# ✅ File exists and is valid: Agora_Image_2023.02.0055.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1475.jpg
# ✅ File exists and is valid: Agora_Image_2012.60.0322.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1475.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1475.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1476.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1476.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1476.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1477.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1477.jpg
# ✅ File exists and is valid: Agora_Image_2013.09.0005.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1483.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1483.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1483.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1483.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0059.jpg
# ✅ File exists and is valid: Agora_Image_2022.03.0752.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0059.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0043.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0043.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0043.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0043.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0043.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0043.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0043.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0044.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0044.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0044.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0044.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0044.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0044.jpg
# ❌ Failed to download Agora:Image:2012.52.0972: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.52.0972
# ✅ File exists and is valid: Agora_Image_2012.54.1447.jpg
# ✅ File exists and is valid: Agora_Image_2012.02.4383.jpg
# ❌ Failed to download Agora:Image:2012.52.0972: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.52.0972
# ❌ Failed to download Agora:Image:2012.52.0972: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.52.0972
# ❌ Failed to download Agora:Image:2012.52.0972: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.52.0972
# ❌ Failed to download Agora:Image:2012.52.0972: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.52.0972
# ✅ File exists and is valid: Agora_Image_2012.55.1486.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1486.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1498.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1498.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1498.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.0918.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0032.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0032.jpg
# ✅ File exists and is valid: Agora_Image_2012.60.0316.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1499.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1499.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1499.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1497.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1497.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1497.jpg
# ❌ Failed to download Agora:Image:2012.55.1488: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.55.1488
# ❌ Failed to download Agora:Image:2012.55.1488: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.55.1488
# ✅ File exists and is valid: Agora_Image_2012.55.1480.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1303.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1480.jpg
# ✅ File exists and is valid: Agora_Image_2012.70.0418.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1481.jpg
# ✅ File exists and is valid: Agora_Image_2012.71.0732.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1481.jpg
# ❌ Failed to download Agora:Image:2012.22.0151: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.22.0151
# ✅ File exists and is valid: Agora_Image_2012.02.7495.jpg
# ✅ File exists and is valid: Agora_Image_2012.50.0887.jpg
# ✅ File exists and is valid: Agora_Image_2012.71.0944.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1479.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1479.jpg
# ✅ File exists and is valid: Agora_Image_2014.01.0037.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1478.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1478.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1478.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1478.jpg
# ✅ File exists and is valid: Agora_Image_2012.76.1503.jpg
# ❌ Failed to download Agora:Image:2012.76.1514: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.76.1514
# ✅ File exists and is valid: Agora_Image_2012.56.0039.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0039.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0039.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0031.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0031.jpg
# ✅ File exists and is valid: Agora_Image_2012.76.1512.jpg
# ✅ File exists and is valid: Agora_Image_2012.76.1512.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1489.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1489.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1489.jpg
# ✅ File exists and is valid: Agora_Image_2012.76.1520.jpg
# ✅ File exists and is valid: Agora_Image_2012.76.1520.jpg
# ✅ File exists and is valid: Agora_Image_2012.76.1520.jpg
# ✅ File exists and is valid: Agora_Image_2012.22.0221.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0055.jpg
# ✅ File exists and is valid: Agora_Image_2012.50.0103.jpg
# ✅ File exists and is valid: Agora_Image_2012.50.0087.jpg
# ❌ Failed to download Agora:Image:2012.56.0030: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.56.0030
# ❌ Failed to download Agora:Image:2012.56.0030: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.56.0030
# ✅ File exists and is valid: Agora_Image_2012.56.0033.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0033.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0053.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0053.jpg
# ✅ File exists and is valid: Agora_Image_2012.50.0087.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0053.jpg
# ✅ File exists and is valid: Agora_Image_2012.50.0086.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0054.jpg
# ✅ File exists and is valid: Agora_Image_2012.50.0084.jpg
# ✅ File exists and is valid: Agora_Image_2012.76.0829.jpg
# ✅ File exists and is valid: Agora_Image_2012.50.0095.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0054.jpg
# ✅ File exists and is valid: Agora_Image_2012.24.0062.jpg
# ✅ File exists and is valid: Agora_Image_2012.76.1518.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0061.jpg
# ✅ File exists and is valid: Agora_Image_2012.50.0109.jpg
# ✅ File exists and is valid: Agora_Image_2012.50.0099.jpg
# ✅ File exists and is valid: Agora_Image_2016.04.0699.jpg
# ✅ File exists and is valid: Agora_Image_2012.76.1518.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0054.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0061.jpg
# ✅ File exists and is valid: Agora_Image_2012.52.0563.jpg
# ❌ Failed to download Agora:Image:2012.53.0838: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.53.0838
# ✅ File exists and is valid: Agora_Image_2012.56.0521.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0521.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0521.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0521.jpg
# ✅ File exists and is valid: Agora_Image_2012.51.1100.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0056.jpg
# ✅ File exists and is valid: Agora_Image_2012.50.0091.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0056.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0056.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0056.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0056.jpg
# ✅ File exists and is valid: Agora_Image_2012.50.0087.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1029.jpg
# ✅ File exists and is valid: Agora_Image_2012.79.1822.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1029.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1029.jpg
# ✅ File exists and is valid: Agora_Image_2012.50.0106.jpg
# ✅ File exists and is valid: Agora_Image_2012.52.0608.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0058.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0058.jpg
# ✅ File exists and is valid: Agora_Image_2012.53.0837.jpg
# ✅ File exists and is valid: Agora_Image_2016.04.0711.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0035.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0035.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0035.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0035.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1485.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1485.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1485.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1485.jpg
# ✅ File exists and is valid: Agora_Image_2013.01.0072.jpg
# ✅ File exists and is valid: Agora_Image_2013.01.0072.jpg
# ✅ File exists and is valid: Agora_Image_2013.01.0072.jpg
# ✅ File exists and is valid: Agora_Image_2013.01.0071.jpg
# ✅ File exists and is valid: Agora_Image_2013.01.0071.jpg
# ✅ File exists and is valid: Agora_Image_2019.05.0721.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1484.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1495.jpg
# ✅ File exists and is valid: Agora_Image_2012.52.0555.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1484.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1487.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1487.jpg
# ✅ File exists and is valid: Agora_Image_2012.50.0102.jpg
# ✅ File exists and is valid: Agora_Image_2007.04.0016.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1487.jpg
# ✅ File exists and is valid: Agora_Image_2012.53.0840.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1487.jpg
# ✅ File exists and is valid: Agora_Image_2012.76.1521.jpg
# ✅ File exists and is valid: Agora_Image_2012.74.0938.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1482.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1482.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1482.jpg
# ❌ Failed to download Agora:Image:2012.56.0045: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.56.0045
# ❌ Failed to download Agora:Image:2014.01.0113: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2014.01.0113
# ❌ Failed to download Agora:Image:2014.01.0113: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2014.01.0113
# ✅ File exists and is valid: Agora_Image_2012.51.0516.jpg
# ✅ File exists and is valid: Agora_Image_2012.52.0567.jpg
# ✅ File exists and is valid: Agora_Image_2012.53.0837.jpg
# ✅ File exists and is valid: Agora_Image_2012.53.0839.jpg
# ✅ File exists and is valid: Agora_Image_2012.53.0850.jpg
# ✅ File exists and is valid: Agora_Image_2012.24.0253.jpg
# ✅ File exists and is valid: Agora_Image_2012.24.0253.jpg
# ✅ File exists and is valid: Agora_Image_2012.53.0850.jpg
# ✅ File exists and is valid: Agora_Image_2016.04.0167.jpg
# ✅ File exists and is valid: Agora_Image_2013.09.0002.jpg
# ✅ File exists and is valid: Agora_Image_2012.53.0850.jpg
# ✅ File exists and is valid: Agora_Image_2013.09.0016.jpg
# ❌ Failed to download Agora:Image:2012.53.0856: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.53.0856
# ❌ Failed to download Agora:Image:2012.53.0856: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.53.0856
# ✅ File exists and is valid: Agora_Image_2013.09.0005.jpg
# ✅ File exists and is valid: Agora_Image_2012.51.1117.jpg
# ✅ File exists and is valid: Agora_Image_2013.09.0011.jpg
# ✅ File exists and is valid: Agora_Image_2012.77.0725.jpg
# ✅ File exists and is valid: Agora_Image_2012.24.0253.jpg
# ✅ File exists and is valid: Agora_Image_2012.74.0131.jpg
# ❌ Failed to download Agora:Image:2014.01.0113: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2014.01.0113
# ✅ File exists and is valid: Agora_Image_2024.02.0757.jpg
# ✅ File exists and is valid: Agora_Image_2024.02.0747.jpg
# ❌ Failed to download Agora:Image:2005.06.0765: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2005.06.0765
# ✅ File exists and is valid: Agora_Image_2012.53.0697.jpg
# ✅ File exists and is valid: Agora_Image_2012.53.0851.jpg
# ✅ File exists and is valid: Agora_Image_2012.53.0687.jpg
# ✅ File exists and is valid: Agora_Image_2012.74.0131.jpg
# ❌ Failed to download Agora:Image:2005.06.0765: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2005.06.0765
# ❌ Failed to download Agora:Image:2012.53.0688: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.53.0688
# ✅ File exists and is valid: Agora_Image_2012.74.0131.jpg
# ✅ File exists and is valid: Agora_Image_2013.09.0013.jpg
# ✅ File exists and is valid: Agora_Image_2012.74.0130.jpg
# ✅ File exists and is valid: Agora_Image_2013.09.0011.jpg
# ✅ File exists and is valid: Agora_Image_2012.70.0796.jpg
# ✅ File exists and is valid: Agora_Image_2012.73.1507.jpg
# ✅ File exists and is valid: Agora_Image_2012.73.1507.jpg
# ✅ File exists and is valid: Agora_Image_2012.73.1507.jpg
# ✅ File exists and is valid: Agora_Image_2012.73.1507.jpg
# ✅ File exists and is valid: Agora_Image_2012.73.1505.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.0927.jpg
# ✅ File exists and is valid: Agora_Image_2000.02.0077.jpg
# ✅ File exists and is valid: Agora_Image_2012.22.0136.jpg
# ✅ File exists and is valid: Agora_Image_2022.03.0766.jpg
# ✅ File exists and is valid: Agora_Image_2012.02.6718.jpg
# ✅ File exists and is valid: Agora_Image_2022.03.0455.jpg
# ✅ File exists and is valid: Agora_Image_2012.77.1807.jpg
# ✅ File exists and is valid: Agora_Image_2007.04.0015.jpg
# ✅ File exists and is valid: Agora_Image_2012.23.0078.jpg
# ✅ File exists and is valid: Agora_Image_2012.51.1100.jpg
# ✅ File exists and is valid: Agora_Image_2022.03.0643.jpg
# ✅ File exists and is valid: Agora_Image_2013.09.0003.jpg
# ✅ File exists and is valid: Agora_Image_2017.03.0401.jpg
# ✅ File exists and is valid: Agora_Image_2012.50.0101.jpg
# ✅ File exists and is valid: Agora_Image_2012.52.0541.jpg
# ✅ File exists and is valid: Agora_Image_2012.52.0541.jpg
# ✅ File exists and is valid: Agora_Image_2012.52.0541.jpg
# ✅ File exists and is valid: Agora_Image_2012.78.1182.jpg
# ✅ File exists and is valid: Agora_Image_2012.50.0092.jpg
# ✅ File exists and is valid: Agora_Image_2012.71.0932.jpg
# ✅ File exists and is valid: Agora_Image_2012.70.0258.jpg
# ❌ Failed to download Agora:Image:2012.53.0504: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.53.0504
# ✅ File exists and is valid: Agora_Image_2012.70.0209.jpg
# ✅ File exists and is valid: Agora_Image_2012.78.0189.jpg
# ✅ File exists and is valid: Agora_Image_2012.70.0251.jpg
# ✅ File exists and is valid: Agora_Image_2012.51.1488.jpg
# ✅ File exists and is valid: Agora_Image_2012.76.0656.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1053.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1053.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1053.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1053.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1053.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1053.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1049.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1049.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1049.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1049.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1050.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1050.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1050.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1050.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1048.jpg
# ✅ File exists and is valid: Agora_Image_2012.76.0825.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1048.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1048.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1048.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1051.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1051.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1051.jpg
# ✅ File exists and is valid: Agora_Image_2016.04.0174.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1052.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1052.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0973.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0973.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0973.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0975.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0975.jpg
# ✅ File exists and is valid: Agora_Image_2012.70.0301.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1061.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1061.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0459.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1061.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0507.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0507.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0507.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0507.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0507.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1056.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1061.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1056.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1056.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1056.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1061.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1055.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1055.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1055.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1060.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0458.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0458.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0458.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0458.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0458.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1054.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1054.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1054.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1054.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1054.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1054.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0509.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0509.jpg
# ✅ File exists and is valid: Agora_Image_2017.03.0395.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0509.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0509.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0508.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0508.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0508.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0508.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1058.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1058.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1058.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1058.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1060.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1057.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1057.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1057.jpg
# ✅ File exists and is valid: Agora_Image_2012.78.0155.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0455.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0455.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0455.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0455.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0455.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1060.jpg
# ✅ File exists and is valid: Agora_Image_2013.09.0002.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1060.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0456.jpg
# ✅ File exists and is valid: Agora_Image_2012.78.0148.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1059.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1059.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1060.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1059.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1059.jpg
# ❌ Failed to download Agora:Image:2009.02.0643: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2009.02.0643
# ✅ File exists and is valid: Agora_Image_2012.56.1045.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1045.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1045.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1045.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0037.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0037.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0037.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0037.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1465.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1465.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1465.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1469.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1469.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1467.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1467.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1467.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1467.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1469.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1468.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1468.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1468.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1046.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1046.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1046.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1047.jpg
# ✅ File exists and is valid: Agora_Image_2017.03.0392.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1047.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1047.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0040.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0040.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0040.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0040.jpg
# ❌ Failed to download Agora:Image:2012.56.0532: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.56.0532
# ❌ Failed to download Agora:Image:2012.56.0532: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.56.0532
# ❌ Failed to download Agora:Image:2012.56.0532: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.56.0532
# ✅ File exists and is valid: Agora_Image_2012.56.0533.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0533.jpg
# ❌ Failed to download Agora:Image:2012.56.0532: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.56.0532
# ✅ File exists and is valid: Agora_Image_2017.03.0398.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.0925.jpg
# ✅ File exists and is valid: Agora_Image_2016.04.0202.jpg
# ✅ File exists and is valid: Agora_Image_2016.04.0203.jpg
# ✅ File exists and is valid: Agora_Image_2013.09.0007.jpg
# ✅ File exists and is valid: Agora_Image_2007.04.0015.jpg
# ✅ File exists and is valid: Agora_Image_2013.09.0011.jpg
# ✅ File exists and is valid: Agora_Image_2012.75.1766.jpg
# ✅ File exists and is valid: Agora_Image_2013.09.0010.jpg
# ✅ File exists and is valid: Agora_Image_2012.75.1763.jpg
# ✅ File exists and is valid: Agora_Image_2012.53.0837.jpg
# ✅ File exists and is valid: Agora_Image_2012.53.0836.jpg
# ✅ File exists and is valid: Agora_Image_2012.75.0895.jpg
# ✅ File exists and is valid: Agora_Image_2012.70.0836.jpg
# ✅ File exists and is valid: Agora_Image_2012.77.1353.jpg
# ✅ File exists and is valid: Agora_Image_2012.77.1350.jpg
# ✅ File exists and is valid: Agora_Image_2012.78.0225.jpg
# ✅ File exists and is valid: Agora_Image_2012.02.6950.jpg
# ✅ File exists and is valid: Agora_Image_2012.77.1512.jpg
# ✅ File exists and is valid: Agora_Image_2012.77.1488.jpg
# ✅ File exists and is valid: Agora_Image_2012.54.1448.jpg
# ✅ File exists and is valid: Agora_Image_2013.09.0021.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0685.jpg
# ✅ File exists and is valid: Agora_Image_2012.53.0692.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0187.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0187.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0187.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0187.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0187.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0187.jpg
# ❌ Failed to download Agora:Image:2018.06.2363: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2018.06.2363
# ✅ File exists and is valid: Agora_Image_2012.56.0188.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0188.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0188.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0188.jpg
# ✅ File exists and is valid: Agora_Image_2014.04.0329.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0060.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0060.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0060.jpg
# ✅ File exists and is valid: Agora_Image_2012.51.1099.jpg
# ✅ File exists and is valid: Agora_Image_2020.03.0955.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0185.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0185.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0185.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0185.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0185.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0185.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0186.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0186.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0186.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0186.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0186.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0186.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0186.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0186.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0186.jpg
# ✅ File exists and is valid: Agora_Image_2012.76.1523.jpg
# ✅ File exists and is valid: Agora_Image_2012.76.1523.jpg
# ✅ File exists and is valid: Agora_Image_2012.76.1523.jpg
# ❌ Failed to download Agora:Image:2012.56.0062: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.56.0062
# ❌ Failed to download Agora:Image:2012.56.0062: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.56.0062
# ❌ Failed to download Agora:Image:2012.76.1510: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.76.1510
# ✅ File exists and is valid: Agora_Image_2012.56.0038.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0038.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0038.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0038.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0038.jpg
# ❌ Failed to download Agora:Image:2012.56.0062: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.56.0062
# ❌ Failed to download Agora:Image:2012.56.0062: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.56.0062
# ❌ Failed to download Agora:Image:2012.56.0062: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.56.0062
# ❌ Failed to download Agora:Image:2012.56.0062: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.56.0062
# ✅ File exists and is valid: Agora_Image_2012.50.0090.jpg
# ✅ File exists and is valid: Agora_Image_2012.50.0089.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.0946.jpg
# ❌ Failed to download Agora:Image:2012.56.0062: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.56.0062
# ✅ File exists and is valid: Agora_Image_2012.50.0088.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0183.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0183.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0183.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0183.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0183.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0183.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0183.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0184.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0184.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0184.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0184.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0184.jpg
# ✅ File exists and is valid: Agora_Image_2016.04.0103.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0545.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0545.jpg
# ✅ File exists and is valid: Agora_Image_2012.77.0772.jpg
# ✅ File exists and is valid: Agora_Image_2013.09.0006.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0545.jpg
# ✅ File exists and is valid: Agora_Image_2014.04.0756.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0525.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0554.jpg
# ✅ File exists and is valid: Agora_Image_2016.04.0087.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0554.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0464.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0464.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0464.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0493.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0493.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0493.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0493.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0496.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0496.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0496.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0489.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0489.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0489.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0494.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0494.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0494.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0494.jpg
# ✅ File exists and is valid: Agora_Image_2012.51.1097.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.0433.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0469.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0469.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0469.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0469.jpg
# ❌ Failed to download Agora:Image:2017.06.0373: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2017.06.0373
# ✅ File exists and is valid: Agora_Image_2012.56.0519.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0519.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0519.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0485.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0485.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0485.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0485.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0485.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0470.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0470.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1044.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1044.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1044.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1044.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.1044.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0463.jpg
# ✅ File exists and is valid: Agora_Image_2013.09.0009.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0463.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0463.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0968.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0968.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0968.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0968.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0968.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0495.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0495.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0495.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0553.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0553.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0553.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0461.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0461.jpg
# ✅ File exists and is valid: Agora_Image_2020.03.0988.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0461.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0461.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0462.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0462.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0462.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0462.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0462.jpg
# ✅ File exists and is valid: Agora_Image_2013.09.0010.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0514.jpg
# ✅ File exists and is valid: Agora_Image_2013.09.0014.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0547.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0547.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0497.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0497.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0497.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0486.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0486.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0486.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0465.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0465.jpg
# ✅ File exists and is valid: Agora_Image_2012.79.1973.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0498.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0510.jpg
# ✅ File exists and is valid: Agora_Image_2012.75.1725.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0510.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0510.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0510.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0498.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0498.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0498.jpg
# ✅ File exists and is valid: Agora_Image_2012.75.1718.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0971.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0971.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0971.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0524.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0524.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0524.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0524.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0524.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0524.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0524.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0524.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0524.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0551.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0551.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0551.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0551.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0551.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0551.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0520.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0520.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0520.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0520.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0563.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0563.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0563.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0552.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0552.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0967.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0967.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0522.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0522.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0522.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0522.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0523.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0523.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0517.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0517.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.0945.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0517.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0517.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0957.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0552.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0552.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.0898.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.0898.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.0898.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.0898.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.0898.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.0898.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.0898.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.0898.jpg
# ✅ File exists and is valid: Agora_Image_2012.70.0754.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.0898.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0036.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0036.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0036.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0036.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1068.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1068.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1068.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1068.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1068.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1068.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0562.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0562.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0562.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0562.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0562.jpg
# ❌ Failed to download Agora:Image:2012.56.0045: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.56.0045
# ✅ File exists and is valid: Agora_Image_2012.56.0561.jpg
# ...
# ❌ Failed to download Agora:Image:2012.56.0549: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.56.0549
# ❌ Failed to download Agora:Image:2012.56.0549: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.56.0549
# ❌ Failed to download Agora:Image:2012.56.0549: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.56.0549
# ❌ Failed to download Agora:Image:2012.56.0549: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.56.0549
# ❌ Failed to download Agora:Image:2012.56.0549: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.56.0549
# ❌ Failed to download Agora:Image:2012.56.0594: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.56.0594
# ✅ File exists and is valid: Agora_Image_2012.57.0820.jpg
# ✅ File exists and is valid: Agora_Image_2012.50.0601.jpg
# ✅ File exists and is valid: Agora_Image_2009.05.0044.jpg
# ✅ File exists and is valid: Agora_Image_2012.51.0512.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1441.jpg
# ✅ File exists and is valid: Agora_Image_2016.01.0017.jpg
# ✅ File exists and is valid: Agora_Image_2016.04.0038.jpg
# ✅ File exists and is valid: Agora_Image_2009.05.0044.jpg
# ❌ Failed to download Agora:Image:2012.23.0290: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.23.0290
# ✅ File exists and is valid: Agora_Image_2012.56.0682.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0374.jpg
# ✅ File exists and is valid: Agora_Image_2012.25.0120.jpg
# ✅ File exists and is valid: Agora_Image_2016.04.0072.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0513.jpg
# ✅ File exists and is valid: Agora_Image_2012.78.1530.jpg
# ✅ File exists and is valid: Agora_Image_2013.09.0014.jpg
# ❌ Failed to download Agora:Image:2018.06.2226: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2018.06.2226
# ✅ File exists and is valid: Agora_Image_2013.09.0012.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0516.jpg
# ✅ File exists and is valid: Agora_Image_2013.09.0016.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0516.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0516.jpg
# ✅ File exists and is valid: Agora_Image_2013.09.0012.jpg
# ✅ File exists and is valid: Agora_Image_2013.09.0016.jpg
# ✅ File exists and is valid: Agora_Image_2013.09.0010.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0515.jpg
# ✅ File exists and is valid: Agora_Image_2013.09.0008.jpg
# ✅ File exists and is valid: Agora_Image_2013.09.0007.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0515.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0515.jpg
# ✅ File exists and is valid: Agora_Image_2016.04.0625.jpg
# ❌ Failed to download Agora:Image:2012.50.0715: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.50.0715
# ✅ File exists and is valid: Agora_Image_2009.05.0005.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1447.jpg
# ✅ File exists and is valid: Agora_Image_2012.73.1573.jpg
# ✅ File exists and is valid: Agora_Image_2004.01.1113.jpg
# ✅ File exists and is valid: Agora_Image_2016.04.0676.jpg
# ✅ File exists and is valid: Agora_Image_2012.02.4314.jpg
# ✅ File exists and is valid: Agora_Image_2012.23.0231.jpg
# ✅ File exists and is valid: Agora_Image_2012.52.0360.jpg
# ❌ Failed to download Agora:Image:2012.22.0194: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.22.0194
# ✅ File exists and is valid: Agora_Image_2012.56.0682.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0682.jpg
# ✅ File exists and is valid: Agora_Image_2012.23.0082.jpg
# ✅ File exists and is valid: Agora_Image_2012.23.0082.jpg
# ✅ File exists and is valid: Agora_Image_2012.23.0079.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1442.jpg
# ❌ Failed to download Agora:Image:2012.50.0708: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.50.0708
# ❌ Failed to download Agora:Image:2012.22.0194: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.22.0194
# ✅ File exists and is valid: Agora_Image_2012.51.0476.jpg
# ✅ File exists and is valid: Agora_Image_2012.52.1471.jpg
# ✅ File exists and is valid: Agora_Image_2017.03.0418.jpg
# ✅ File exists and is valid: Agora_Image_2012.54.1446.jpg
# ❌ Failed to download Agora:Image:2012.55.0842: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.55.0842
# ✅ File exists and is valid: Agora_Image_2012.02.4304.jpg
# ❌ Failed to download Agora:Image:2012.56.0955: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.56.0955
# ❌ Failed to download Agora:Image:2012.55.0842: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.55.0842
# ✅ File exists and is valid: Agora_Image_2016.04.0034.jpg
# ✅ File exists and is valid: Agora_Image_2012.51.1108.jpg
# ✅ File exists and is valid: Agora_Image_2012.50.0702.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.0966.jpg
# ✅ File exists and is valid: Agora_Image_2012.51.1108.jpg
# ✅ File exists and is valid: Agora_Image_2022.03.0623.jpg
# ✅ File exists and is valid: Agora_Image_2022.03.0622.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0055.jpg
# ✅ File exists and is valid: Agora_Image_2012.02.6753.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1455.jpg
# ✅ File exists and is valid: Agora_Image_2022.03.0743.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.0425.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1455.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1455.jpg
# ✅ File exists and is valid: Agora_Image_2012.23.0087.jpg
# ✅ File exists and is valid: Agora_Image_2012.73.1576.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0682.jpg
# ✅ File exists and is valid: Agora_Image_2012.50.0874.jpg
# ✅ File exists and is valid: Agora_Image_2012.50.0536.jpg
# ✅ File exists and is valid: Agora_Image_2012.54.1450.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1443.jpg
# ✅ File exists and is valid: Agora_Image_2012.74.0848.jpg
# ✅ File exists and is valid: Agora_Image_2011.04.0154.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0288.jpg
# ✅ File exists and is valid: Agora_Image_2012.74.0842.jpg
# ✅ File exists and is valid: Agora_Image_2012.74.0841.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1345.jpg
# ✅ File exists and is valid: Agora_Image_2012.22.0003.jpg
# ✅ File exists and is valid: Agora_Image_2012.23.0335.jpg
# ✅ File exists and is valid: Agora_Image_2012.74.0800.jpg
# ❌ Failed to download Agora:Image:2013.06.0708: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2013.06.0708
# ❌ Failed to download Agora:Image:2012.22.0395: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.22.0395
# ❌ Failed to download Agora:Image:2012.55.1444: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.55.1444
# ✅ File exists and is valid: Agora_Image_2012.55.0926.jpg
# ✅ File exists and is valid: Agora_Image_2012.51.1103.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0491.jpg
# ✅ File exists and is valid: Agora_Image_2019.05.0750.jpg
# ✅ File exists and is valid: Agora_Image_2008.03.0232.jpg
# ✅ File exists and is valid: Agora_Image_2019.05.0616.jpg
# ✅ File exists and is valid: Agora_Image_2019.05.0621.jpg
# ✅ File exists and is valid: Agora_Image_2007.01.1608.jpg
# ✅ File exists and is valid: Agora_Image_2012.25.0120.jpg
# ✅ File exists and is valid: Agora_Image_2007.10.0086.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1443.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1443.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.0931.jpg
# ✅ File exists and is valid: Agora_Image_2012.50.0879.jpg
# ✅ File exists and is valid: Agora_Image_2012.50.0154.jpg
# ✅ File exists and is valid: Agora_Image_2012.52.0537.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0593.jpg
# ❌ Failed to download Agora:Image:2012.53.0007: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.53.0007
# ✅ File exists and is valid: Agora_Image_2012.70.1089.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0386.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0386.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0386.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0386.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0386.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0386.jpg
# ✅ File exists and is valid: Agora_Image_2012.74.0583.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0386.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0386.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0386.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0386.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0386.jpg
# ❌ Failed to download Agora:Image:2012.56.0387: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.56.0387
# ❌ Failed to download Agora:Image:2012.56.0387: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.56.0387
# ❌ Failed to download Agora:Image:2012.56.0387: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.56.0387
# ❌ Failed to download Agora:Image:2012.56.0387: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.56.0387
# ✅ File exists and is valid: Agora_Image_2012.57.1193.jpg
# ❌ Failed to download Agora:Image:2012.56.0387: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.56.0387
# ❌ Failed to download Agora:Image:2012.56.0387: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.56.0387
# ✅ File exists and is valid: Agora_Image_2012.74.0902.jpg
# ✅ File exists and is valid: Agora_Image_2012.73.1576.jpg
# ✅ File exists and is valid: Agora_Image_2012.85.0530.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.0944.jpg
# ❌ Failed to download Agora:Image:2009.02.0547: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2009.02.0547
# ✅ File exists and is valid: Agora_Image_2012.55.1451.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1451.jpg
# ✅ File exists and is valid: Agora_Image_2016.04.0068.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.0965.jpg
# ❌ Failed to download Agora:Image:2012.50.0713: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.50.0713
# ❌ Failed to download Agora:Image:2012.50.0713: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.50.0713
# ✅ File exists and is valid: Agora_Image_2012.55.1439.jpg
# ❌ Failed to download Agora:Image:2012.50.0713: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.50.0713
# ✅ File exists and is valid: Agora_Image_2012.56.0491.jpg
# ✅ File exists and is valid: Agora_Image_2015.04.0164.jpg
# ❌ Failed to download Agora:Image:2012.50.0713: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.50.0713
# ✅ File exists and is valid: Agora_Image_2012.55.1438.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1439.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1439.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0511.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0511.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1436.jpg
# ✅ File exists and is valid: Agora_Image_2012.50.0710.jpg
# ✅ File exists and is valid: Agora_Image_2012.02.8322.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0490.jpg
# ✅ File exists and is valid: Agora_Image_2012.73.1576.jpg
# ✅ File exists and is valid: Agora_Image_2012.25.0120.jpg
# ✅ File exists and is valid: Agora_Image_2017.03.0450.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0491.jpg
# ✅ File exists and is valid: Agora_Image_2012.52.0939.jpg
# ✅ File exists and is valid: Agora_Image_2020.05.0340.jpg
# ✅ File exists and is valid: Agora_Image_2015.04.0188.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0491.jpg
# ✅ File exists and is valid: Agora_Image_2017.03.0450.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1436.jpg
# ✅ File exists and is valid: Agora_Image_2012.50.0878.jpg
# ✅ File exists and is valid: Agora_Image_2015.04.0167.jpg
# ✅ File exists and is valid: Agora_Image_2019.05.0773.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0593.jpg
# ❌ Failed to download Agora:Image:2012.56.1346: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.56.1346
# ✅ File exists and is valid: Agora_Image_2012.25.0120.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.0649.jpg
# ✅ File exists and is valid: Agora_Image_2013.09.0007.jpg
# ✅ File exists and is valid: Agora_Image_2016.04.0074.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1440.jpg
# ❌ Failed to download Agora:Image:2012.51.1046: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.51.1046
# ✅ File exists and is valid: Agora_Image_2012.02.7752.jpg
# ✅ File exists and is valid: Agora_Image_2012.81.1803.jpg
# ✅ File exists and is valid: Agora_Image_2012.54.1446.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.0963.jpg
# ❌ Failed to download Agora:Image:2012.56.0419: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.56.0419
# ❌ Failed to download Agora:Image:2012.56.0419: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.56.0419
# ✅ File exists and is valid: Agora_Image_2012.55.0963.jpg
# ❌ Failed to download Agora:Image:2012.56.0955: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.56.0955
# ❌ Failed to download Agora:Image:2012.56.0955: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.56.0955
# ❌ Failed to download Agora:Image:2012.56.0955: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.56.0955
# ❌ Failed to download Agora:Image:2012.56.0955: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.56.0955
# ✅ File exists and is valid: Agora_Image_2012.26.0302.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.0436.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0491.jpg
# ❌ Failed to download Agora:Image:2012.20.0362: 404 Client Error: Not Found for url: https://ascsa.net/image?type=full&id=Agora%3AImage%3A2012.20.0362
# ✅ File exists and is valid: Agora_Image_2012.55.0931.jpg
# ✅ File exists and is valid: Agora_Image_2012.74.1071.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1438.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1449.jpg
# ✅ File exists and is valid: Agora_Image_2017.03.0450.jpg
# ✅ File exists and is valid: Agora_Image_2017.03.0450.jpg
# ✅ File exists and is valid: Agora_Image_2012.73.1576.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1445.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.0965.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1440.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1440.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0595.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1452.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0491.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1453.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1262.jpg
# ✅ File exists and is valid: Agora_Image_2012.56.0490.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1261.jpg
# ✅ File exists and is valid: Agora_Image_2012.25.0184.jpg
# ✅ File exists and is valid: Agora_Image_2012.55.1268.jpg

# %% [markdown]
# #### Image Stats After Download
#
# Count the downloaded image files and how many are unique:

# %%
data_states["filtered"] = data.loc[data["ValidChronology"]]

image_stats["downloaded_image_file"] = {
    state: int(records["ImageFilename"].notna().sum())
    for state, records in data_states.items()
}
image_stats["unique_image_files"] = {
    state: records["ImageFilename"].nunique()
    for state, records in data_states.items()
}

display(image_stats_table(image_stats))
# Out:
#                       unfiltered                          filtered             \
#                            count % of total % of previous    count % of total
# total_records               2000     100.0%             -     1910     100.0%
# media_link_in_Parent        1366      68.3%         68.3%     1315      68.8%
# image_type_link             1047      52.3%         76.6%     1011      52.9%
# downloaded_image_file        954      47.7%         91.1%      923      48.3%
# unique_image_files           479      23.9%         50.2%      472      24.7%
#
#
#                       % of previous
# total_records                     -
# media_link_in_Parent          68.8%
# image_type_link               76.9%
# downloaded_image_file         91.3%
# unique_image_files            51.1%

# %% [markdown]
# #### Image Stats Visualization
#
# Nested proportional-area chart of successive record subsets:
# - box **areas** are proportional to record counts
# - all record counts and percentages refer to the filtered dataset
# - the initial/unfiltered dataset record count is shown as a dashed frame.

# %%
ASPECT = 3.0 / 2  # width : height of every box
C = 0.3
EDGE_COLOR = (0, 0, 0, 0.4)

# layout in axes units: label column (left of boxes) + in-box value columns
LABEL_W = 0.36  # width reserved for the outside labels
LABEL_WRAP = 28  # wrap labels to this many characters
X_NUM = 0.085  # right edge of the count column
X_P1 = 0.099  # first pipe
X_VAL = 0.126  # "% of valid" column
X_P2 = 0.316  # second pipe
X_PREV = 0.347  # "% of previous" column
FS = 11


def plot_nested_subsets(stages, initial=None, denom_label="valid", figsize=(14, 10), cmap="RdYlGn"):
    """Nested proportional-area chart of successive record subsets.

    stages : list of (count, label), outermost subset first.
    initial: optional (count, label) drawn as a dashed reference frame.
    Every box keeps the same aspect ratio and its side lengths scale with
    sqrt(count / stages[0][0]), so box AREA is proportional to count.
    """
    base = stages[0][0]
    fig, ax = plt.subplots(figsize=figsize)
    colors = (1. - C) * plt.get_cmap(cmap)(list(map(lambda stage: stage[0] / base, stages))) + C * np.ones(
        (len(stages), 4))

    def draw(count, face, ls="-", lw=1.0):
        s = np.sqrt(count / base)
        ax.add_patch(FancyBboxPatch(
            (0, 0), ASPECT * s, s,
            boxstyle="round,pad=0,rounding_size=0",
            facecolor=face, edgecolor=EDGE_COLOR, linestyle=ls, lw=lw))
        return s

    def label_row(s, label, border=True):
        # separator rule + right-aligned label, outside the boxes on the left
        if border: ax.plot([-LABEL_W, 0], [s, s], color=EDGE_COLOR, lw=1, zorder=1, clip_on=False)
        ax.text(-0.025, s - 0.008, textwrap.fill(label, LABEL_WRAP),
                fontsize=FS, weight="bold", va="top", ha="right",
                multialignment="right", linespacing=1.15)

    def value_row(y, count, pcts):
        # count | % of valid | % of previous  -- fixed-x columns
        ax.text(X_NUM, y, f"{count}", fontsize=FS, weight="bold", va="center", ha="right")
        for x_pipe, x_txt, txt in ((X_P1, X_VAL, pcts[0] if pcts else None),
                                   (X_P2, X_PREV, pcts[1] if len(pcts) > 1 else None)):
            if txt:
                ax.text(x_pipe, y, "|", fontsize=FS, color=(0, 0, 0, 0.45), va="center", ha="center")
                ax.text(x_txt, y, txt, fontsize=FS, weight="bold", va="center")

    if initial is not None:
        s0 = draw(initial[0], (0, 0, 0, 0.15), ls="--", lw=1.4)
        label_row(s0 + 0.005, initial[1], border=False)
        value_row(s0 - 0.013, initial[0], [])

    sides = [np.sqrt(c / base) for c, _ in stages]
    prev = initial[0] if initial is not None else None
    for i, (count, label) in enumerate(stages):
        s = draw(count, colors[i], lw=0.8)
        if i == 0:
            pcts = [f"{count / prev:.0%} of initial"] if prev else []
        else:
            pcts = [f"{count / base:.0%} of {denom_label}"]
            if prev != base:
                pcts.append(f"{count / prev:.0%} of previous")
        # visible sliver of this box = between its top edge and the next box's
        sliver = s - (sides[i + 1] if i + 1 < len(sides) else 0)
        y_offset = sliver / 2 if sliver < 0.05 else 0.025  # too thin -> center
        label_row(s, label)
        value_row(s - y_offset, count, pcts)
        prev = count

    lim = np.sqrt(initial[0] / base) if initial is not None else 1.0
    ax.set_xlim(-LABEL_W - 0.02, ASPECT * lim + 0.02)
    ax.set_ylim(-0.02, lim + 0.06)
    ax.set_aspect("equal")
    ax.axis("off")
    fig.tight_layout()
    plt.show()

# %%
stage_labels = {
    "total_records": "records with valid chronology",
    "media_link_in_Parent": "records with a media link in the Parent field",
    "image_type_link": "records with image-type link",
    "downloaded_image_file": "records with a downloaded image file",
    "unique_image_files": "unique image files",
}
stages = [(image_stats[k]["filtered"], lbl) for k, lbl in stage_labels.items()]

plot_nested_subsets(stages, initial=(image_stats["total_records"]["unfiltered"], "initial total"))

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# - **HTML Decoding**: Converts encoded HTML entities (like `&lt;` → `<`) using `html.unescape`.
# - **HTML Tag Removal**: Removes all HTML tags, such as `<i>` and `<b>`, using a regular expression.
# - **Normalize Whitespace**: Ensures clean formatting by collapsing tabs, multiple spaces, and newlines.
# - **Special Character Removal**: Removes symbols and characters, keeping only letters, numbers, spaces, and selected punctuation (`.,!?-;:`). Retaining punctuation may preserve context relevance.
# - **Lowercasing**: Makes text consistent for textual analysis.

# %%
# Function to clean text data
def clean_text(text):
    # Handle missing values
    if pd.isna(text):
        return ""

    # Decode HTML entities (e.g., &lt;b&gt; -> <b>)
    text = html.unescape(text)

    # Remove HTML tags
    text = re.sub(r"<.*?>", "", text)

    # Remove special characters (retain alphanumeric and some punctuation)
    text = re.sub(r"[^\w\s.,;:!?-]", "", text)

    # Convert to lowercase
    text = text.lower()

    # Normalize whitespace (remove line breaks, tabs, extra spaces)
    text = re.sub(r"[\r\n\t]+", " ", text)
    text = re.sub(r"\s+", " ", text).strip()

    return text

# %%
# Cleaning individual columns
# Combine into the single 'CombinedText' column:
data.loc[:, "FullText"] = (
        data["Text"].apply(clean_text) + " " +
        data["Classification"].apply(clean_text) + " " +
        data["Class"].apply(clean_text) + " " +
        data["Dimensions"].apply(clean_text)
)

# %%
data["FullText"]
# Out:
# 0       foot missing. offset neck and echinoid mouth; ...
# 1       spreading ring foot with torus outer and conve...
# 2       flaring ring foot. torus mouth. ridge at junct...
# 3       ring foot. echinoid mouth inset from neck and ...
# 4       echinus ring foot. torus mouth; strap handles....
#                               ...
# 1995    fragment of rim and floor with handle. deep ba...
# 1996    handles missing. basin and lid; handles probab...
# 1997    small series. plain flat-topped rim; flaring b...
# 1998    small series. rim flat on top, roughly moulded...
# 1999    stand and floor fragment. lower edge of stand ...
# Name: FullText, Length: 2000, dtype: object

# %% [markdown]
# ## Final Feature Selection

# %%
data.columns
# Out:
# Index(['Id', 'Collection', 'Type', 'Name', 'UserGroup', 'AgoraVolume',
#        'AgoraNumber', 'Text', 'PublishedNumber', 'Classification', 'Class',
#        'Deposit', 'Dimensions', 'Chronology', 'ChronologyRange', 'Sort',
#        'Sibling', 'Edges', 'Bibliography', 'Parent', 'AgoraLetter',
#        'ValidChronology', 'StartYear', 'EndYear', 'HistoricalPeriod',
#        'MidpointYear', 'YearRange', 'ImageFilename', 'FullText'],
#       dtype='object')

# %%
data_pp = data[["Id", "FullText", "ImageFilename", "StartYear", "EndYear", "MidpointYear", "YearRange",
                "HistoricalPeriod", "ValidChronology"]]
data_pp
# Out:
#                                Id  \
# 0        Agora:Object:Agora XII:1
# 1        Agora:Object:Agora XII:2
# 2        Agora:Object:Agora XII:3
# 3        Agora:Object:Agora XII:4
# 4        Agora:Object:Agora XII:5
# ...                           ...
# 1995  Agora:Object:Agora XII:2036
# 1996  Agora:Object:Agora XII:2037
# 1997  Agora:Object:Agora XII:2038
# 1998  Agora:Object:Agora XII:2039
# 1999  Agora:Object:Agora XII:2040
#
#                                                FullText  \
# 0     foot missing. offset neck and echinoid mouth; ...
# 1     spreading ring foot with torus outer and conve...
# 2     flaring ring foot. torus mouth. ridge at junct...
# 3     ring foot. echinoid mouth inset from neck and ...
# 4     echinus ring foot. torus mouth; strap handles....
# ...                                                 ...
# 1995  fragment of rim and floor with handle. deep ba...
# 1996  handles missing. basin and lid; handles probab...
# 1997  small series. plain flat-topped rim; flaring b...
# 1998  small series. rim flat on top, roughly moulded...
# 1999  stand and floor fragment. lower edge of stand ...
#
#                      ImageFilename  StartYear  EndYear  MidpointYear  \
# 0     Agora_Image_2012.54.1450.jpg       -575     -550        -562.5
# 1                              NaN       -525     -500        -512.5
# 2                              NaN       -500     -500        -500.0
# 3                              NaN       -500     -500        -500.0
# 4     Agora_Image_2012.27.0009.jpg       -525     -500        -512.5
# ...                            ...        ...      ...           ...
# 1995                           NaN       -350     -320        -335.0
# 1996  Agora_Image_2012.55.1261.jpg       -350     -301        -325.5
# 1997  Agora_Image_2012.25.0184.jpg       -435     -425        -430.0
# 1998  Agora_Image_2012.55.1268.jpg       -375     -325        -350.0
# 1999                           NaN       -400     -300        -350.0
#
#       YearRange HistoricalPeriod  ValidChronology
# 0            25          Archaic             True
# 1            25          Archaic             True
# 2             0          Archaic             True
# 3             0          Archaic             True
# 4            25          Archaic             True
# ...         ...              ...              ...
# 1995         30        Classical             True
# 1996         49        Classical             True
# 1997         10        Classical             True
# 1998         50        Classical             True
# 1999        100        Classical            False
#
# [2000 rows x 9 columns]

# %% [markdown]
# ## Export Processed Data

# %%
data_pp.to_csv(path + 'agora12_data_pp.csv', index=False, encoding='utf-8', sep=',', header=True)
