# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from itertools import product
from sklearn.preprocessing import MinMaxScaler

# %%
from utils import d_types_methods, get_unique, get_color_map, plot_metric_in_groups, plot_metric_points, \
    plot_pivot_table, plot_best_of_each, plot_best_by_data_type

# %%
scoreboard = pd.read_csv("cv_scoreboard.csv")

# %%
# Unique values
targets, models, features = get_unique(scoreboard, ["target", "model", "features"])

# %%
# Consistent color mapping
model_colors = get_color_map(models, "Set1")
feature_colors = get_color_map(features, "Set2")

# %%
for target in targets:
    subset = scoreboard[scoreboard["target"] == target]
    plot_metric_in_groups(subset, "mae", "features", "model", model_colors)

# %%
for target in targets:
    subset = scoreboard[scoreboard["target"] == target]
    plot_metric_in_groups(subset, "mae", "model", "features", feature_colors)

# %%
import numpy as np

for target in targets:
    subset = scoreboard[scoreboard["target"] == target]
    print(np.min(subset["r2"].tolist() + [0.0]))
    plot_metric_points(subset, "r2", "features", "model", model_colors, lim=1)
# Out:
# -1.648159308743947
# -3.518834893826748

# %%
for target in targets:
    subset = scoreboard[scoreboard["target"] == target]
    plot_metric_points(subset, "r2", "model", "features", feature_colors, lim=1)

# %%
for target in targets:
    subset = scoreboard[scoreboard["target"] == target]
    plot_pivot_table(subset, "mae", models, features)

# %%
for target in targets:
    subset = scoreboard[scoreboard["target"] == target]
    plot_best_of_each(subset, "mae", "features", "model", model_colors)

# %%
for target in targets:
    subset = scoreboard[scoreboard["target"] == target]
    plot_best_of_each(subset, "mae", "model", "features", feature_colors)

# %%
for target in targets:
    subset = scoreboard[scoreboard["target"] == target]
    plot_best_by_data_type(subset, "mae", model_colors)
