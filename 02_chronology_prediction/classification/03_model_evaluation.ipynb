# %%
import pandas as pd
from utils import get_unique, get_color_map, plot_metric_in_groups, plot_pivot_table, plot_best_of_each, plot_best_by_data_type

# %%
scoreboard = pd.read_csv("cv_scoreboard.csv")

# %%
# Unique values
models, features = get_unique(scoreboard, ["model", "features"])

# %%
# Consistent color mapping
model_colors = get_color_map(models, "Set1")
feature_colors = get_color_map(features, "Set2")

# %%
plot_metric_in_groups(scoreboard, "accuracy", "features", "model", model_colors, ylim=1)

# %%
plot_metric_in_groups(scoreboard, "accuracy", "model", "features", feature_colors, ylim=1)

# %%
plot_pivot_table(scoreboard, "accuracy", models, features)

# %%
plot_best_of_each(scoreboard, "accuracy", "features", "model", model_colors, ylim=1)

# %%
plot_best_of_each(scoreboard, "accuracy", "model", "features", feature_colors, ylim=1)

# %%
plot_best_by_data_type(scoreboard, "accuracy", model_colors, lim=1)
